# %%
import glob
import plotly.express as px
import pandas as pd

# %%
dm_data = {} # get rid if the uni of indiana tags since we can't really tell what that is

for fname in glob.glob("data/*.profile.txt"):
    with open(fname, "r") as f:
        dm_data[fname.split("/")[1].split(".")[0]] = {row.split("\t")[0]: row.split("\t")[1] for row in f.read().split("\n") if len(row.split("\t"))>1}

# %%
dm_data
# Out:
# {'104': {'Prevotella': '8647836',
#   'Bacteroides': '1905763',
#   'Faecalibacterium': '744079',
#   'Ruminococcus': '716317',
#   'Lachnobacterium': '689068',
#   'Clostridium': '498446',
#   'Blautia': '466477',
#   'Alistipes': '355561',
#   'Dorea': '304352',
#   'Megasphaera': '258433',
#   'Sutterella': '220632',
#   'Dialister': '213583',
#   'Bifidobacterium': '168242',
#   'Lactobacillus': '135463',
#   'Roseburia': '116765',
#   'Parabacteroides': '114986',
#   'Oscillibacter': '80455',
#   'Solobacterium': '69708',
#   'Paraprevotella': '67836',
#   'Eubacterium': '59554',
#   'Collinsella': '53729',
#   'Lachnospira': '48502',
#   'Barnesiella': '36181',
#   'Coprococcus': '31498',
#   'Odoribacter': '29057',
#   'Desulfovibrio': '28572',
#   'Slackia': '24482',
#   'Butyricicoccus': '23468',
#   'Xylanibacter': '22488',
#   'Butyrivibrio': '20020',
#   'Butyricimonas': '19042',
#   'Phascolarctobacterium': '17954',
#   'Acidaminococcus': '12870',
#   'Catenibacterium': '9267',
#   'Eggerthella': '5934',
#   'Streptococcus': '5128',
#   'Halomonas': '4973',
#   'Olsenella': '4971',
#   'Pseudobutyrivibrio': '4529',
#   'Actinomyces': '4388',
#   'Bacillus': '4373',
#   'Coprobacillus': '3660',
#   'Selenomonas': '3284',
#   'Subdoligranulum': '3195',
#   'Fusobacterium': '2914',
#   'Corynebacterium': '2684',
#   'Porphyromonas': '2522',
#   'Lachnoclostridium': '2294',
#   'Treponema': '2257',
#   'Anaerotruncus': '1885',
#   'Listeria': '1626',
#   'Veillonella': '1378',
#   'Pseudomonas': '1357',
#   'Peptoniphilus': '1068',
#   'Robinsoniella': '934',
#   'Finegoldia': '933',
#   'Klebsiella': '838',
#   'Streptomyces': '807',
#   'Anaeromassilibacillus': '701',
#   'Azospirillum': '655',
#   'Enterobacter': '635',
#   'Marvinbryantia': '616',
#   'Massiliomicrobiota': '594',
#   'Gemmiger': '578',
#   'Flavobacterium': '435',
#   'Cellulomonas': '420',
#   'Succiniclasticum': '419',
#   'Enterococcus': '400',
#   'Anaerococcus': '389',
#   'Oxalobacter': '351',
#   'Dysgonomonas': '345',
#   'Brachyspira': '342',
#   'Paenibacillus': '303',
#   'Cloacibacillus': '259',
#   'Providencia': '252',
#   'Megamonas': '250',
#   'Pantoea': '243',
#   'Helicobacter': '227',
#   'Weissella': '226',
#   'Akkermansia': '211',
#   'Achromobacter': '201',
#   'Ralstonia': '170',
#   'Sneathia': '168',
#   'Franconibacter': '162',
#   'Staphylococcus': '159',
#   'Acinetobacter': '146',
#   'Leuconostoc': '144',
#   'Anaerotignum': '139',
#   'Exiguobacterium': '134',
#   'Atopobium': '123',
#   'Aeromonas': '122',
#   'Anaerostipes': '106',
#   'Campylobacter': '102',
#   'Blastococcus': '101',
#   'Anaerofustis': '87',
#   'Propionibacterium': '86',
#   'Oribacterium': '86',
#   'Anaerosporobacter': '83',
#   'Citrobacter': '71',
#   'Brevibacterium': '70',
#   'Edwardsiella': '69',
#   'Sanguibacteroides': '62',
#   'Phyllobacterium': '58',
#   'Nesterenkonia': '54',
#   'Succinatimonas': '43',
#   'Pelosinus': '38',
#   'Granulicatella': '36',
#   'Cryptobacterium': '34',
#   'Morganella': '32',
#   'Garciella': '23',
#   'Gemella': '21',
#   'Adlercreutzia': '19',
#   'Rothia': '15',
#   'Propionimicrobium': '15',
#   'Negativicoccus': '12',
#   'Neisseria': '10',
#   'Proteus': '9',
#   'Pediococcus': '8',
#   'Sporolactobacillus': '5',
#   'Peptostreptococcus': '3'},
#  '1': {'Bacteroides': '3577852',
#   'Ruminococcus': '2785909',
#   'Faecalibacterium': '1975044',
#   'Clostridium': '1882814',
#   'Blautia': '1022805',
#   'Lachnobacterium': '995757',
#   'Alistipes': '630226',
#   'Bifidobacterium': '510993',
#   'Prevotella': '433184',
#   'Oscillibacter': '330188',
#   'Dorea': '242050',
#   'Barnesiella': '233838',
#   'Lachnospira': '218951',
#   'Eubacterium': '212041',
#   'Solobacterium': '204672',
#   'Collinsella': '199790',
#   'Dialister': '186288',
#   'Odoribacter': '156353',
#   'Roseburia': '145338',
#   'Desulfovibrio': '122632',
#   'Coprococcus': '119223',
#   'Butyricimonas': '92539',
#   'Parabacteroides': '76216',
#   'Sutterella': '60720',
#   'Adlercreutzia': '59217',
#   'Butyrivibrio': '58770',
#   'Eggerthella': '44210',
#   'Butyricicoccus': '33855',
#   'Lactobacillus': '25895',
#   'Akkermansia': '18272',
#   'Bacillus': '12939',
#   'Veillonella': '12771',
#   'Coprobacillus': '11613',
#   'Enterococcus': '11440',
#   'Fusobacterium': '11265',
#   'Subdoligranulum': '11014',
#   'Pseudobutyrivibrio': '8060',
#   'Actinomyces': '7113',
#   'Streptococcus': '7079',
#   'Olsenella': '6993',
#   'Paraprevotella': '5991',
#   'Klebsiella': '5916',
#   'Halomonas': '5900',
#   'Lachnoclostridium': '5830',
#   'Corynebacterium': '5680',
#   'Phascolarctobacterium': '5405',
#   'Megasphaera': '5238',
#   'Anaerotruncus': '4495',
#   'Slackia': '4437',
#   'Selenomonas': '4216',
#   'Anaeromassilibacillus': '4200',
#   'Enterobacter': '4107',
#   'Pseudomonas': '4014',
#   'Listeria': '2747',
#   'Xylanibacter': '2431',
#   'Gemmiger': '2291',
#   'Flavobacterium': '2156',
#   'Marvinbryantia': '2101',
#   'Streptomyces': '1962',
#   'Cloacibacillus': '1771',
#   'Oxalobacter': '1699',
#   'Robinsoniella': '1649',
#   'Acidaminococcus': '1534',
#   'Paenibacillus': '1410',
#   'Catenibacterium': '1228',
#   'Citrobacter': '1208',
#   'Succiniclasticum': '1159',
#   'Staphylococcus': '1157',
#   'Azospirillum': '1145',
#   'Anaerococcus': '1071',
#   'Pantoea': '1033',
#   'Anaerostipes': '1021',
#   'Providencia': '991',
#   'Massiliomicrobiota': '938',
#   'Cellulomonas': '838',
#   'Acinetobacter': '673',
#   'Dysgonomonas': '670',
#   'Treponema': '667',
#   'Achromobacter': '647',
#   'Brachyspira': '564',
#   'Peptoniphilus': '563',
#   'Atopobium': '551',
#   'Anaerofustis': '549',
#   'Porphyromonas': '540',
#   'Helicobacter': '493',
#   'Anaerosporobacter': '471',
#   'Weissella': '440',
#   'Ralstonia': '429',
#   'Propionibacterium': '404',
#   'Aeromonas': '403',
#   'Succinatimonas': '329',
#   'Campylobacter': '320',
#   'Megamonas': '297',
#   'Blastococcus': '274',
#   'Garciella': '263',
#   'Leuconostoc': '259',
#   'Phyllobacterium': '243',
#   'Sneathia': '231',
#   'Anaerotignum': '226',
#   'Finegoldia': '218',
#   'Pelosinus': '198',
#   'Brevibacterium': '184',
#   'Edwardsiella': '168',
#   'Oribacterium': '155',
#   'Sanguibacteroides': '124',
#   'Cryptobacterium': '103',
#   'Morganella': '81',
#   'Franconibacter': '75',
#   'Proteus': '67',
#   'Neisseria': '56',
#   'Rothia': '49',
#   'Exiguobacterium': '45',
#   'Gemella': '40',
#   'Propionimicrobium': '38',
#   'Granulicatella': '37',
#   'Nesterenkonia': '29',
#   'Sporolactobacillus': '24',
#   'Peptostreptococcus': '11',
#   'Pediococcus': '11',
#   'Negativicoccus': '6'},
#  '100': {'Prevotella': '5547132',
#   'Clostridium': '1259655',
#   'Ruminococcus': '1140555',
#   'Blautia': '1093262',
#   'Alistipes': '960806',
#   'Bacteroides': '883414',
#   'Faecalibacterium': '772438',
#   'Solobacterium': '443004',
#   'Butyrivibrio': '439327',
#   'Bifidobacterium': '381172',
#   'Oscillibacter': '365454',
#   'Lachnobacterium': '337921',
#   'Dialister': '285255',
#   'Dorea': '225409',
#   'Catenibacterium': '181367',
#   'Collinsella': '158744',
#   'Roseburia': '144400',
#   'Megasphaera': '120088',
#   'Desulfovibrio': '85570',
#   'Parabacteroides': '77003',
#   'Eubacterium': '74291',
#   'Sutterella': '40937',
#   'Lachnospira': '40382',
#   'Coprococcus': '36154',
#   'Selenomonas': '35258',
#   'Butyricimonas': '33997',
#   'Paraprevotella': '33415',
#   'Lactobacillus': '30868',
#   'Eggerthella': '29470',
#   'Butyricicoccus': '23674',
#   'Olsenella': '21688',
#   'Acidaminococcus': '18798',
#   'Slackia': '15091',
#   'Phascolarctobacterium': '14882',
#   'Bacillus': '9509',
#   'Fusobacterium': '9355',
#   'Odoribacter': '9110',
#   'Streptococcus': '7965',
#   'Xylanibacter': '6714',
#   'Actinomyces': '5748',
#   'Subdoligranulum': '5409',
#   'Halomonas': '5243',
#   'Coprobacillus': '4842',
#   'Pseudobutyrivibrio': '4839',
#   'Barnesiella': '4650',
#   'Corynebacterium': '4443',
#   'Anaerotruncus': '4254',
#   'Anaeromassilibacillus': '4205',
#   'Lachnoclostridium': '3130',
#   'Pseudomonas': '3070',
#   'Klebsiella': '3046',
#   'Gemmiger': '2509',
#   'Listeria': '2196',
#   'Veillonella': '1998',
#   'Enterobacter': '1968',
#   'Streptomyces': '1460',
#   'Oxalobacter': '1452',
#   'Enterococcus': '1214',
#   'Robinsoniella': '1209',
#   'Marvinbryantia': '1151',
#   'Massiliomicrobiota': '1014',
#   'Azospirillum': '1011',
#   'Paenibacillus': '937',
#   'Staphylococcus': '895',
#   'Flavobacterium': '845',
#   'Porphyromonas': '796',
#   'Cellulomonas': '767',
#   'Providencia': '710',
#   'Pantoea': '686',
#   'Peptoniphilus': '656',
#   'Helicobacter': '617',
#   'Anaerococcus': '614',
#   'Akkermansia': '611',
#   'Treponema': '608',
#   'Campylobacter': '579',
#   'Succiniclasticum': '546',
#   'Dysgonomonas': '471',
#   'Cloacibacillus': '469',
#   'Brachyspira': '427',
#   'Propionibacterium': '420',
#   'Achromobacter': '331',
#   'Succinatimonas': '319',
#   'Acinetobacter': '315',
#   'Citrobacter': '312',
#   'Aeromonas': '297',
#   'Ralstonia': '289',
#   'Finegoldia': '285',
#   'Anaerosporobacter': '273',
#   'Sneathia': '245',
#   'Weissella': '241',
#   'Pelosinus': '202',
#   'Megamonas': '194',
#   'Anaerofustis': '175',
#   'Oribacterium': '174',
#   'Phyllobacterium': '172',
#   'Rothia': '151',
#   'Brevibacterium': '135',
#   'Edwardsiella': '124',
#   'Leuconostoc': '112',
#   'Blastococcus': '109',
#   'Sanguibacteroides': '108',
#   'Anaerostipes': '103',
#   'Exiguobacterium': '87',
#   'Neisseria': '68',
#   'Adlercreutzia': '67',
#   'Cryptobacterium': '63',
#   'Atopobium': '58',
#   'Gemella': '55',
#   'Morganella': '43',
#   'Nesterenkonia': '42',
#   'Franconibacter': '42',
#   'Sporolactobacillus': '40',
#   'Anaerotignum': '38',
#   'Garciella': '38',
#   'Propionimicrobium': '36',
#   'Proteus': '35',
#   'Granulicatella': '34',
#   'Pediococcus': '24',
#   'Peptostreptococcus': '21',
#   'Negativicoccus': '18'},
#  '4': {'Bacteroides': '5422460',
#   'Clostridium': '2609003',
#   'Ruminococcus': '1786056',
#   'Blautia': '851774',
#   'Alistipes': '744727',
#   'Prevotella': '699236',
#   'Bifidobacterium': '570703',
#   'Faecalibacterium': '521859',
#   'Oscillibacter': '391224',
#   'Parabacteroides': '369745',
#   'Dorea': '254436',
#   'Solobacterium': '203639',
#   'Lachnobacterium': '183437',
#   'Desulfovibrio': '170742',
#   'Collinsella': '153747',
#   'Catenibacterium': '152956',
#   'Eubacterium': '131712',
#   'Paraprevotella': '128897',
#   'Azospirillum': '114327',
#   'Butyricimonas': '101632',
#   'Butyricicoccus': '91550',
#   'Barnesiella': '89996',
#   'Roseburia': '85609',
#   'Odoribacter': '82213',
#   'Coprococcus': '63817',
#   'Dialister': '46937',
#   'Sutterella': '46763',
#   'Subdoligranulum': '39926',
#   'Lachnospira': '31139',
#   'Slackia': '30954',
#   'Butyrivibrio': '28419',
#   'Lactobacillus': '25481',
#   'Phascolarctobacterium': '25346',
#   'Fusobacterium': '20533',
#   'Akkermansia': '15595',
#   'Bacillus': '12918',
#   'Anaeromassilibacillus': '11956',
#   'Eggerthella': '11663',
#   'Coprobacillus': '10412',
#   'Streptococcus': '7014',
#   'Actinomyces': '6797',
#   'Megasphaera': '6623',
#   'Halomonas': '6270',
#   'Anaerotruncus': '5650',
#   'Olsenella': '5536',
#   'Corynebacterium': '5317',
#   'Xylanibacter': '5116',
#   'Klebsiella': '4522',
#   'Veillonella': '4417',
#   'Pseudomonas': '3844',
#   'Pseudobutyrivibrio': '3779',
#   'Listeria': '2690',
#   'Enterobacter': '2640',
#   'Selenomonas': '2526',
#   'Gemmiger': '2330',
#   'Lachnoclostridium': '2263',
#   'Acidaminococcus': '2197',
#   'Streptomyces': '1859',
#   'Oxalobacter': '1593',
#   'Robinsoniella': '1529',
#   'Paenibacillus': '1502',
#   'Staphylococcus': '1420',
#   'Massiliomicrobiota': '1386',
#   'Anaerococcus': '1328',
#   'Providencia': '1190',
#   'Marvinbryantia': '1171',
#   'Porphyromonas': '1114',
#   'Cloacibacillus': '1109',
#   'Enterococcus': '1097',
#   'Pantoea': '1041',
#   'Succiniclasticum': '916',
#   'Peptoniphilus': '844',
#   'Dysgonomonas': '814',
#   'Treponema': '744',
#   'Helicobacter': '727',
#   'Propionibacterium': '710',
#   'Flavobacterium': '676',
#   'Acinetobacter': '626',
#   'Atopobium': '607',
#   'Anaerosporobacter': '601',
#   'Brachyspira': '594',
#   'Achromobacter': '547',
#   'Anaerofustis': '513',
#   'Ralstonia': '453',
#   'Weissella': '443',
#   'Campylobacter': '393',
#   'Cellulomonas': '379',
#   'Proteus': '359',
#   'Phyllobacterium': '347',
#   'Finegoldia': '329',
#   'Aeromonas': '292',
#   'Sneathia': '281',
#   'Megamonas': '278',
#   'Pelosinus': '273',
#   'Leuconostoc': '260',
#   'Oribacterium': '246',
#   'Citrobacter': '226',
#   'Succinatimonas': '196',
#   'Blastococcus': '181',
#   'Anaerotignum': '174',
#   'Sanguibacteroides': '165',
#   'Brevibacterium': '158',
#   'Rothia': '152',
#   'Anaerostipes': '152',
#   'Edwardsiella': '139',
#   'Neisseria': '101',
#   'Morganella': '83',
#   'Gemella': '76',
#   'Franconibacter': '55',
#   'Adlercreutzia': '54',
#   'Peptostreptococcus': '45',
#   'Exiguobacterium': '43',
#   'Nesterenkonia': '36',
#   'Cryptobacterium': '33',
#   'Garciella': '33',
#   'Propionimicrobium': '26',
#   'Sporolactobacillus': '19',
#   'Pediococcus': '17',
#   'Granulicatella': '17',
#   'Negativicoccus': '12'},
#  '14': {'Bacteroides': '3685197',
#   'Prevotella': '2919282',
#   'Clostridium': '1705783',
#   'Bifidobacterium': '1213839',
#   'Alistipes': '1114537',
#   'Ruminococcus': '1053653',
#   'Blautia': '905343',
#   'Oscillibacter': '535053',
#   'Odoribacter': '424304',
#   'Dorea': '420001',
#   'Sutterella': '370992',
#   'Parabacteroides': '270411',
#   'Faecalibacterium': '260524',
#   'Paraprevotella': '236617',
#   'Solobacterium': '223083',
#   'Lachnobacterium': '190972',
#   'Collinsella': '164512',
#   'Barnesiella': '148182',
#   'Roseburia': '131451',
#   'Desulfovibrio': '123624',
#   'Eubacterium': '92576',
#   'Butyricimonas': '87352',
#   'Phascolarctobacterium': '85481',
#   'Coprococcus': '80117',
#   'Catenibacterium': '67273',
#   'Dialister': '62936',
#   'Lactobacillus': '44065',
#   'Butyricicoccus': '25509',
#   'Eggerthella': '19742',
#   'Lachnospira': '18045',
#   'Veillonella': '17921',
#   'Akkermansia': '17558',
#   'Butyrivibrio': '15772',
#   'Fusobacterium': '14571',
#   'Actinomyces': '12825',
#   'Bacillus': '12205',
#   'Streptococcus': '9976',
#   'Olsenella': '9861',
#   'Pseudobutyrivibrio': '9497',
#   'Xylanibacter': '9388',
#   'Slackia': '9036',
#   'Megasphaera': '7939',
#   'Klebsiella': '7636',
#   'Coprobacillus': '7617',
#   'Corynebacterium': '6997',
#   'Halomonas': '6723',
#   'Enterobacter': '4969',
#   'Subdoligranulum': '4200',
#   'Selenomonas': '4001',
#   'Pseudomonas': '3799',
#   'Anaerotruncus': '3064',
#   'Anaeromassilibacillus': '2915',
#   'Listeria': '2898',
#   'Lachnoclostridium': '2616',
#   'Gemmiger': '2490',
#   'Citrobacter': '2330',
#   'Marvinbryantia': '1969',
#   'Streptomyces': '1948',
#   'Oxalobacter': '1788',
#   'Acidaminococcus': '1724',
#   'Robinsoniella': '1696',
#   'Providencia': '1693',
#   'Porphyromonas': '1678',
#   'Enterococcus': '1453',
#   'Paenibacillus': '1338',
#   'Flavobacterium': '1311',
#   'Staphylococcus': '1195',
#   'Pantoea': '1181',
#   'Anaerococcus': '1144',
#   'Azospirillum': '1108',
#   'Campylobacter': '1062',
#   'Massiliomicrobiota': '1046',
#   'Cloacibacillus': '748',
#   'Dysgonomonas': '743',
#   'Succiniclasticum': '700',
#   'Propionibacterium': '646',
#   'Peptoniphilus': '552',
#   'Helicobacter': '531',
#   'Acinetobacter': '518',
#   'Brachyspira': '518',
#   'Treponema': '506',
#   'Achromobacter': '482',
#   'Ralstonia': '468',
#   'Weissella': '421',
#   'Sanguibacteroides': '376',
#   'Edwardsiella': '372',
#   'Cellulomonas': '358',
#   'Phyllobacterium': '298',
#   'Anaerostipes': '290',
#   'Aeromonas': '286',
#   'Brevibacterium': '263',
#   'Sneathia': '255',
#   'Neisseria': '250',
#   'Finegoldia': '244',
#   'Succinatimonas': '232',
#   'Pelosinus': '227',
#   'Blastococcus': '226',
#   'Anaerosporobacter': '223',
#   'Atopobium': '212',
#   'Cryptobacterium': '211',
#   'Megamonas': '194',
#   'Adlercreutzia': '193',
#   'Oribacterium': '178',
#   'Anaerofustis': '160',
#   'Garciella': '157',
#   'Leuconostoc': '153',
#   'Morganella': '134',
#   'Exiguobacterium': '115',
#   'Granulicatella': '112',
#   'Propionimicrobium': '92',
#   'Rothia': '86',
#   'Franconibacter': '85',
#   'Proteus': '71',
#   'Gemella': '46',
#   'Anaerotignum': '45',
#   'Nesterenkonia': '43',
#   'Peptostreptococcus': '41',
#   'Pediococcus': '33',
#   'Negativicoccus': '24',
#   'Sporolactobacillus': '20'},
#  '97': {'Bacteroides': '2898144',
#   'Prevotella': '2433864',
#   'Clostridium': '2106115',
#   'Ruminococcus': '1688403',
#   'Blautia': '1179960',
#   'Alistipes': '979683',
#   'Faecalibacterium': '800328',
#   'Lachnobacterium': '778288',
#   'Solobacterium': '754109',
#   'Butyrivibrio': '484521',
#   'Dorea': '451118',
#   'Oscillibacter': '338294',
#   'Roseburia': '315311',
#   'Dialister': '256610',
#   'Sutterella': '245133',
#   'Barnesiella': '225196',
#   'Parabacteroides': '207826',
#   'Eubacterium': '168735',
#   'Collinsella': '145520',
#   'Desulfovibrio': '145402',
#   'Odoribacter': '96872',
#   'Coprococcus': '78446',
#   'Catenibacterium': '69819',
#   'Lachnospira': '69659',
#   'Paraprevotella': '60850',
#   'Bifidobacterium': '59926',
#   'Streptococcus': '45657',
#   'Selenomonas': '40856',
#   'Butyricicoccus': '33010',
#   'Olsenella': '25669',
#   'Lactobacillus': '25483',
#   'Eggerthella': '24121',
#   'Butyricimonas': '22406',
#   'Megasphaera': '22405',
#   'Enterococcus': '19028',
#   'Coprobacillus': '17824',
#   'Slackia': '16328',
#   'Fusobacterium': '14176',
#   'Bacillus': '13061',
#   'Actinomyces': '11098',
#   'Subdoligranulum': '9118',
#   'Pseudobutyrivibrio': '8306',
#   'Klebsiella': '7057',
#   'Xylanibacter': '6874',
#   'Halomonas': '6672',
#   'Phascolarctobacterium': '5796',
#   'Corynebacterium': '4702',
#   'Acidaminococcus': '4572',
#   'Enterobacter': '4487',
#   'Anaeromassilibacillus': '4417',
#   'Anaerotruncus': '4206',
#   'Lachnoclostridium': '3849',
#   'Veillonella': '3812',
#   'Marvinbryantia': '3718',
#   'Pseudomonas': '3621',
#   'Gemmiger': '2744',
#   'Akkermansia': '2594',
#   'Listeria': '2522',
#   'Robinsoniella': '2016',
#   'Citrobacter': '2009',
#   'Streptomyces': '1543',
#   'Cloacibacillus': '1487',
#   'Leuconostoc': '1427',
#   'Flavobacterium': '1381',
#   'Massiliomicrobiota': '1363',
#   'Propionimicrobium': '1349',
#   'Staphylococcus': '1328',
#   'Treponema': '1281',
#   'Porphyromonas': '1191',
#   'Oxalobacter': '1168',
#   'Pantoea': '1165',
#   'Paenibacillus': '1054',
#   'Anaerococcus': '971',
#   'Providencia': '888',
#   'Dysgonomonas': '800',
#   'Helicobacter': '787',
#   'Azospirillum': '763',
#   'Peptoniphilus': '753',
#   'Succiniclasticum': '652',
#   'Brachyspira': '572',
#   'Sanguibacteroides': '554',
#   'Acinetobacter': '535',
#   'Ralstonia': '512',
#   'Megamonas': '477',
#   'Propionibacterium': '476',
#   'Achromobacter': '476',
#   'Weissella': '466',
#   'Granulicatella': '433',
#   'Cellulomonas': '394',
#   'Campylobacter': '374',
#   'Aeromonas': '364',
#   'Anaerosporobacter': '350',
#   'Finegoldia': '343',
#   'Anaerofustis': '335',
#   'Proteus': '316',
#   'Sneathia': '273',
#   'Adlercreutzia': '261',
#   'Phyllobacterium': '228',
#   'Oribacterium': '206',
#   'Blastococcus': '182',
#   'Anaerostipes': '170',
#   'Gemella': '168',
#   'Brevibacterium': '166',
#   'Atopobium': '159',
#   'Pelosinus': '155',
#   'Edwardsiella': '140',
#   'Exiguobacterium': '112',
#   'Succinatimonas': '104',
#   'Cryptobacterium': '101',
#   'Anaerotignum': '87',
#   'Morganella': '74',
#   'Garciella': '64',
#   'Neisseria': '52',
#   'Franconibacter': '40',
#   'Nesterenkonia': '37',
#   'Rothia': '24',
#   'Pediococcus': '19',
#   'Peptostreptococcus': '17',
#   'Sporolactobacillus': '14',
#   'Negativicoccus': '9'}}

# %%
max_depth = 21
run_trimmed = True

kraken_data = {}

# work through all of the kraken stuff
for fname in glob.glob("outputs/*/kraken2/*.kreport"):
    with open(fname, 'r') as f:
        data = f.read().split("\n") # split data into separate rows
        parsed_data = {}
        
        curr_tag = ['-' for i in range(0, max_depth)]
        for i in data:
            curr_row = i.split("\t") # the data within rows is tab-delimited

            # create a tag structure
            curr_n = curr_row[-1].split("  ")
    
            if curr_n[-1] != '': # skip rows w-out taxon names (mostly to deal w empty entries)
                try:
                    curr_tag[len(curr_n)-1] = curr_n[-1]
                except:
                    print(curr_n) # just a contingency to see when we end up deeper than expected
                    
                for j in range(len(curr_n), max_depth):
                    curr_tag[j] = '-'
                    
                # extract the percentage of aligned reads
                #parsed_data['\t'.join(curr_tag)] = curr_row[0].replace(" ", "")
                parsed_data['\t'.join(curr_tag)] = curr_row[1].replace(" ", "")
                #parsed_data['\t'.join(curr_tag)] = curr_row[2].replace(" ", "")
                
        kraken_data[fname.split("/")[-3].split("_")[2]] = dict(parsed_data)
        if fname.split("/")[-3].split("_")[2] in dm_data:
            kraken_data[fname.split("/")[-3].split("_")[2]+"_dm"] = dm_data[fname.split("/")[-3].split("_")[2]]

# %%
genus_map = {}

for k, v in kraken_data.items():
    for s, _ in v.items():
        for t in s.split("\t")[5:]:
            genus_map[t] = s.split("\t")[5]

# convert genus to phylum
dm_phyl_data = {} # get rid if the uni of indiana tags since we can't really tell what that is

for s, v in dm_data.items():
    dm_phyl_data[s] = {}
    
    for g, c in v.items():
        if g in genus_map:
            if genus_map[g] not in dm_phyl_data[s]:
                dm_phyl_data[s][genus_map[g]] = 0
            dm_phyl_data[s][genus_map[g]] += int(c)

for k, v in dm_phyl_data.items():
    print(k)
    kraken_data[str(k)+"_dm"] = v
# Out:
# 104
# 1
# 100
# 4
# 14
# 97

# %%
genus_map
# Out:
# {'-': 'Fungi incertae sedis',
#  'Bacteroidetes': 'Bacteroidetes',
#  'Bacteroidia': 'Bacteroidetes',
#  'Bacteroidales': 'Bacteroidetes',
#  'Prevotellaceae': 'Bacteroidetes',
#  'Prevotella': 'Bacteroidetes',
#  'Prevotella copri': 'Bacteroidetes',
#  'Prevotella copri DSM 18205': 'Bacteroidetes',
#  'unclassified Prevotella': 'Bacteroidetes',
#  'Prevotella sp. AM23-5': 'Bacteroidetes',
#  'Prevotella sp. AM34-19LB': 'Bacteroidetes',
#  'Prevotella sp. BCRC 81118': 'Bacteroidetes',
#  'Prevotella sp. Marseille-P4119': 'Bacteroidetes',
#  'Prevotella sp. P4-51': 'Bacteroidetes',
#  'Prevotella sp. P2-180': 'Bacteroidetes',
#  'Prevotella sp. 885': 'Bacteroidetes',
#  'Prevotella sp. MGM1': 'Bacteroidetes',
#  'Prevotella sp. P3-122': 'Bacteroidetes',
#  'Prevotella sp. ne3005': 'Bacteroidetes',
#  'Prevotella sp. P4-98': 'Bacteroidetes',
#  'Prevotella sp. BV3P1': 'Bacteroidetes',
#  'Prevotella sp. AGR2160': 'Bacteroidetes',
#  'Prevotella sp. P5-92': 'Bacteroidetes',
#  'Prevotella sp. HUN102': 'Bacteroidetes',
#  'Prevotella sp. P5-126': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 820': 'Bacteroidetes',
#  'Prevotella sp. S7 MS 2': 'Bacteroidetes',
#  'Prevotella sp. OH937_COT-195': 'Bacteroidetes',
#  'Prevotella sp. tf2-5': 'Bacteroidetes',
#  'Prevotella sp. Marseille-P4334': 'Bacteroidetes',
#  'Prevotella sp. MA2016': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 317': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 317 str. F0108': 'Bacteroidetes',
#  'Prevotella sp. F0091': 'Bacteroidetes',
#  'Prevotella sp. C561': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 376': 'Bacteroidetes',
#  'Prevotella sp. S7-1-8': 'Bacteroidetes',
#  'Prevotella sp. P5-64': 'Bacteroidetes',
#  'Prevotella sp. P5-108': 'Bacteroidetes',
#  'Prevotella sp. KH2C16': 'Bacteroidetes',
#  'Prevotella sp. P4-119': 'Bacteroidetes',
#  'Prevotella sp. RM4': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 472': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 472 str. F0295': 'Bacteroidetes',
#  'Prevotella sp. P5-50': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 306': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 306 str. F0472': 'Bacteroidetes',
#  'Prevotella sp. tc2-28': 'Bacteroidetes',
#  'Prevotella sp. lc2012': 'Bacteroidetes',
#  'Prevotella sp. BP1-145': 'Bacteroidetes',
#  'Prevotella sp. BP1-148': 'Bacteroidetes',
#  'Prevotella sp. HJM029': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 299': 'Bacteroidetes',
#  'Prevotella sp. oral taxon 299 str. F0039': 'Bacteroidetes',
#  'Prevotella sp. ICM33': 'Bacteroidetes',
#  'Prevotella pectinovora': 'Bacteroidetes',
#  'Prevotella marseillensis': 'Bacteroidetes',
#  'Prevotella disiens': 'Bacteroidetes',
#  'Prevotella disiens FB035-09AN': 'Bacteroidetes',
#  'Prevotella disiens DNF00882': 'Bacteroidetes',
#  'Prevotella lascolaii': 'Bacteroidetes',
#  'Prevotella bivia': 'Bacteroidetes',
#  'Prevotella bivia DNF00650': 'Bacteroidetes',
#  'Prevotella bivia DSM 20514': 'Bacteroidetes',
#  'Prevotella bivia DNF00320': 'Bacteroidetes',
#  'Prevotella stercorea': 'Bacteroidetes',
#  'Prevotella stercorea DSM 18206': 'Bacteroidetes',
#  'Prevotella bryantii': 'Bacteroidetes',
#  'Prevotella bryantii B14': 'Bacteroidetes',
#  'Prevotella bryantii C21a': 'Bacteroidetes',
#  'Prevotella buccae': 'Bacteroidetes',
#  'Prevotella buccae D17': 'Bacteroidetes',
#  'Prevotella buccae ATCC 33574': 'Bacteroidetes',
#  'Prevotella multisaccharivorax': 'Bacteroidetes',
#  'Prevotella multisaccharivorax DSM 17128': 'Bacteroidetes',
#  'Prevotella melaninogenica': 'Bacteroidetes',
#  'Prevotella melaninogenica DNF00666': 'Bacteroidetes',
#  'Prevotella melaninogenica D18': 'Bacteroidetes',
#  'Prevotella timonensis': 'Bacteroidetes',
#  'Prevotella timonensis S9-PR14': 'Bacteroidetes',
#  'Prevotella timonensis 4401737 = DSM 22865 = JCM 15640': 'Bacteroidetes',
#  'Prevotella timonensis CRIS 5C-B1': 'Bacteroidetes',
#  'Prevotella multiformis': 'Bacteroidetes',
#  'Prevotella multiformis DSM 16608': 'Bacteroidetes',
#  'Prevotella buccalis': 'Bacteroidetes',
#  'Prevotella buccalis ATCC 35310': 'Bacteroidetes',
#  'Prevotella buccalis DNF00853': 'Bacteroidetes',
#  'Prevotella buccalis DNF00985': 'Bacteroidetes',
#  'Prevotella brevis': 'Bacteroidetes',
#  'Prevotella brevis ATCC 19188': 'Bacteroidetes',
#  'Prevotella intermedia': 'Bacteroidetes',
#  'Prevotella intermedia ZT': 'Bacteroidetes',
#  'Prevotella corporis': 'Bacteroidetes',
#  'Prevotella corporis DSM 18810 = JCM 8529': 'Bacteroidetes',
#  'Prevotella albensis': 'Bacteroidetes',
#  'Prevotella albensis DSM 11370 = JCM 12258': 'Bacteroidetes',
#  'Prevotella veroralis': 'Bacteroidetes',
#  'Prevotella veroralis F0319': 'Bacteroidetes',
#  'Prevotella dentalis': 'Bacteroidetes',
#  'Prevotella dentalis DSM 3688': 'Bacteroidetes',
#  'Prevotella falsenii': 'Bacteroidetes',
#  'Prevotella falsenii DSM 22864 = JCM 15124': 'Bacteroidetes',
#  'Prevotella ihumii': 'Bacteroidetes',
#  'Prevotella aurantiaca': 'Bacteroidetes',
#  'Prevotella aurantiaca JCM 15754': 'Bacteroidetes',
#  'Prevotella histicola': 'Bacteroidetes',
#  'Prevotella histicola JCM 15637 = DNF00424': 'Bacteroidetes',
#  'Prevotella bergensis': 'Bacteroidetes',
#  'Prevotella bergensis DSM 17361': 'Bacteroidetes',
#  'Prevotella paludivivens': 'Bacteroidetes',
#  'Prevotella paludivivens DSM 17968 = JCM 13650': 'Bacteroidetes',
#  'Prevotella pleuritidis': 'Bacteroidetes',
#  'Prevotella pleuritidis F0068': 'Bacteroidetes',
#  'Prevotella pallens': 'Bacteroidetes',
#  'Prevotella ruminicola': 'Bacteroidetes',
#  'Prevotella ruminicola 23': 'Bacteroidetes',
#  'Prevotella ruminicola Ga6B6': 'Bacteroidetes',
#  'Prevotella colorans': 'Bacteroidetes',
#  'Prevotella saccharolytica': 'Bacteroidetes',
#  'Prevotella saccharolytica F0055': 'Bacteroidetes',
#  'Prevotella saccharolytica JCM 17484': 'Bacteroidetes',
#  'Prevotella oulorum': 'Bacteroidetes',
#  'Prevotella oulorum F0390': 'Bacteroidetes',
#  'Prevotella koreensis': 'Bacteroidetes',
#  'Prevotella dentasini': 'Bacteroidetes',
#  'Prevotella dentasini JCM 15908': 'Bacteroidetes',
#  'Prevotella baroniae': 'Bacteroidetes',
#  'Prevotella baroniae DSM 16972 = JCM 13447': 'Bacteroidetes',
#  'Prevotella oris': 'Bacteroidetes',
#  'Prevotella oris C735': 'Bacteroidetes',
#  'Prevotella fusca': 'Bacteroidetes',
#  'Prevotella fusca JCM 17724': 'Bacteroidetes',
#  'Prevotella denticola': 'Bacteroidetes',
#  'Prevotella denticola F0289': 'Bacteroidetes',
#  'Prevotella amnii': 'Bacteroidetes',
#  'Prevotella amnii CRIS 21A-A': 'Bacteroidetes',
#  'Prevotella amnii DSM 23384 = JCM 14753': 'Bacteroidetes',
#  'Prevotella salivae': 'Bacteroidetes',
#  'Prevotella micans': 'Bacteroidetes',
#  'Prevotella oryzae': 'Bacteroidetes',
#  'Prevotella oryzae DSM 17970': 'Bacteroidetes',
#  'Prevotella conceptionensis': 'Bacteroidetes',
#  'Prevotella conceptionensis 9403948': 'Bacteroidetes',
#  'Prevotella brunnea': 'Bacteroidetes',
#  'Prevotella nanceiensis': 'Bacteroidetes',
#  'Prevotella nanceiensis DSM 19126 = JCM 15639': 'Bacteroidetes',
#  'Prevotella jejuni': 'Bacteroidetes',
#  'Prevotella enoeca': 'Bacteroidetes',
#  'Prevotella oralis': 'Bacteroidetes',
#  'Prevotella maculosa': 'Bacteroidetes',
#  'Prevotella maculosa OT 289': 'Bacteroidetes',
#  'Prevotella marshii': 'Bacteroidetes',
#  'Prevotella marshii DSM 16973 = JCM 13450': 'Bacteroidetes',
#  'Prevotella nigrescens': 'Bacteroidetes',
#  'Prevotella nigrescens CC14M': 'Bacteroidetes',
#  'Prevotella aff. ruminicola Tc2-24': 'Bacteroidetes',
#  'Hallella seregens': 'Bacteroidetes',
#  'Hallella seregens ATCC 51272': 'Bacteroidetes',
#  'Paraprevotella': 'Bacteroidetes',
#  'Paraprevotella clara': 'Bacteroidetes',
#  'Paraprevotella xylaniphila': 'Bacteroidetes',
#  'Paraprevotella xylaniphila YIT 11841': 'Bacteroidetes',
#  'unclassified Prevotellaceae': 'Bacteroidetes',
#  'Prevotellaceae bacterium LKV-178-WT-2A': 'Bacteroidetes',
#  'Prevotellaceae bacterium HUN156': 'Bacteroidetes',
#  'Prevotellaceae bacterium MN60': 'Bacteroidetes',
#  'Prevotellaceae bacterium KH2P17': 'Bacteroidetes',
#  'Alloprevotella': 'Bacteroidetes',
#  'Alloprevotella tannerae': 'Bacteroidetes',
#  'Alloprevotella tannerae ATCC 51259': 'Bacteroidetes',
#  'Alloprevotella rava': 'Bacteroidetes',
#  'Alloprevotella rava F0323': 'Bacteroidetes',
#  'unclassified Alloprevotella': 'Bacteroidetes',
#  'Alloprevotella sp. OH1205_COT-284': 'Bacteroidetes',
#  'Metaprevotella': 'Bacteroidetes',
#  'Metaprevotella massiliensis': 'Bacteroidetes',
#  'Bacteroidaceae': 'Bacteroidetes',
#  'Bacteroides': 'Bacteroidetes',
#  'Bacteroides coprophilus': 'Bacteroidetes',
#  'Bacteroides coprophilus DSM 18228 = JCM 13818': 'Bacteroidetes',
#  'Bacteroides coprophilus JCM 13817': 'Bacteroidetes',
#  'Bacteroides coprophilus JCM 13816': 'Bacteroidetes',
#  'Bacteroides stercoris': 'Bacteroidetes',
#  'Bacteroides stercoris CC31F': 'Bacteroidetes',
#  'Bacteroides stercoris ATCC 43183': 'Bacteroidetes',
#  'Bacteroides caccae': 'Bacteroidetes',
#  'Bacteroides caccae ATCC 43185': 'Bacteroidetes',
#  'Bacteroides vulgatus': 'Bacteroidetes',
#  'Bacteroides vulgatus CL09T03C04': 'Bacteroidetes',
#  'Bacteroides vulgatus str. 3975 RP4': 'Bacteroidetes',
#  'Bacteroides vulgatus str. 3775 SR(B) 19': 'Bacteroidetes',
#  'Bacteroides vulgatus dnLKV7': 'Bacteroidetes',
#  'Bacteroides vulgatus PC510': 'Bacteroidetes',
#  'Bacteroides vulgatus str. 3775 SL(B) 10 (iv)': 'Bacteroidetes',
#  'Bacteroides ovatus': 'Bacteroidetes',
#  'Bacteroides ovatus SD CMC 3f': 'Bacteroidetes',
#  'Bacteroides ovatus CL02T12C04': 'Bacteroidetes',
#  'Bacteroides ovatus CL03T12C18': 'Bacteroidetes',
#  'Bacteroides ovatus str. 3725 D1 iv': 'Bacteroidetes',
#  'Bacteroides ovatus str. 3725 D9 iii': 'Bacteroidetes',
#  'Bacteroides uniformis': 'Bacteroidetes',
#  'Bacteroides uniformis dnLKV2': 'Bacteroidetes',
#  'Bacteroides uniformis str. 3978 T3 ii': 'Bacteroidetes',
#  'Bacteroides uniformis ATCC 8492': 'Bacteroidetes',
#  'Bacteroides uniformis str. 3978 T3 i': 'Bacteroidetes',
#  'Bacteroides thetaiotaomicron': 'Bacteroidetes',
#  'Bacteroides thetaiotaomicron dnLKV9': 'Bacteroidetes',
#  'Bacteroides thetaiotaomicron VPI-5482': 'Bacteroidetes',
#  'Bacteroides plebeius': 'Bacteroidetes',
#  'unclassified Bacteroides': 'Bacteroidetes',
#  'Bacteroides sp. OF03-11BH': 'Bacteroidetes',
#  'Bacteroides sp. An279': 'Bacteroidetes',
#  'Bacteroides sp. AM16-15': 'Bacteroidetes',
#  'Bacteroides sp. AF20-13LB': 'Bacteroidetes',
#  'Bacteroides sp. 1_1_14': 'Bacteroidetes',
#  'Bacteroides sp. An19': 'Bacteroidetes',
#  'Bacteroides sp. 1_1_30': 'Bacteroidetes',
#  'Bacteroides sp. An51A': 'Bacteroidetes',
#  'Bacteroides sp. An269': 'Bacteroidetes',
#  'Bacteroides sp. CF01-10NS': 'Bacteroidetes',
#  'Bacteroides sp. HMSC067B03': 'Bacteroidetes',
#  'Bacteroides sp. D22': 'Bacteroidetes',
#  'Bacteroides sp. KCTC 15687': 'Bacteroidetes',
#  'Bacteroides sp. 4_3_47FAA': 'Bacteroidetes',
#  'Bacteroides sp. AR29': 'Bacteroidetes',
#  'Bacteroides sp. 4_1_36': 'Bacteroidetes',
#  'Bacteroides sp. Marseille-P3684': 'Bacteroidetes',
#  'Bacteroides sp. 3_1_33FAA': 'Bacteroidetes',
#  'Bacteroides sp. 2_1_33B': 'Bacteroidetes',
#  'Bacteroides sp. AM37-9': 'Bacteroidetes',
#  'Bacteroides sp. D2': 'Bacteroidetes',
#  'Bacteroides sp. An322': 'Bacteroidetes',
#  'Bacteroides sp. 3_1_23': 'Bacteroidetes',
#  'Bacteroides sp. 2_2_4': 'Bacteroidetes',
#  'Bacteroides sp. CBA7301': 'Bacteroidetes',
#  'Bacteroides sp. HPS0048': 'Bacteroidetes',
#  'Bacteroides sp. AR20': 'Bacteroidetes',
#  'Bacteroides sp. AF32-8BH': 'Bacteroidetes',
#  'Bacteroides sp. AM23-18': 'Bacteroidetes',
#  'Bacteroides sp. 14(A)': 'Bacteroidetes',
#  'Bacteroides sp. NMBE5': 'Bacteroidetes',
#  'Bacteroides sp. HMSC068A09': 'Bacteroidetes',
#  'Bacteroides sp. AM16-13': 'Bacteroidetes',
#  'Bacteroides sp. AF25-38AC': 'Bacteroidetes',
#  'Bacteroides sp. AF39-16AC': 'Bacteroidetes',
#  'Bacteroides sp. 3_1_19': 'Bacteroidetes',
#  'Bacteroides sp. AF25-18': 'Bacteroidetes',
#  'Bacteroides sp. A1C1': 'Bacteroidetes',
#  'Bacteroides sp. 9_1_42FAA': 'Bacteroidetes',
#  'Bacteroides sp. KFT8': 'Bacteroidetes',
#  'Bacteroides sp. AM56-10ce': 'Bacteroidetes',
#  'Bacteroides sp. HMSC073E02': 'Bacteroidetes',
#  'Bacteroides sp. AM54-2NS': 'Bacteroidetes',
#  'Bacteroides sp. 3_1_40A': 'Bacteroidetes',
#  'Bacteroides sp. AM32-11AC': 'Bacteroidetes',
#  'Bacteroides sp. AF34-31BH': 'Bacteroidetes',
#  'Bacteroides sp. AM41-16': 'Bacteroidetes',
#  'Bacteroides sp. AF29-11': 'Bacteroidetes',
#  'Bacteroides sp. AM51-7': 'Bacteroidetes',
#  'Bacteroides sp. OF02-3LB': 'Bacteroidetes',
#  'Bacteroides sp. AF37-16AC': 'Bacteroidetes',
#  'Bacteroides sp. AF33-23': 'Bacteroidetes',
#  'Bacteroides sp. AM23-12': 'Bacteroidetes',
#  'Bacteroides sp. AM27-13': 'Bacteroidetes',
#  'Bacteroides sp. AF32-15BH': 'Bacteroidetes',
#  'Bacteroides sp. AF18-33': 'Bacteroidetes',
#  'Bacteroides sp. AM18-9': 'Bacteroidetes',
#  'Bacteroides sp. 3_1_13': 'Bacteroidetes',
#  'Bacteroides sp. AM30-16': 'Bacteroidetes',
#  'Bacteroides sp. D20': 'Bacteroidetes',
#  'Bacteroides sp. AM44-19': 'Bacteroidetes',
#  'Bacteroides sp. AF39-10AT': 'Bacteroidetes',
#  'Bacteroides sp. AF26-10BH': 'Bacteroidetes',
#  'Bacteroides sp. AF17-1': 'Bacteroidetes',
#  'Bacteroides sp. AM07-18': 'Bacteroidetes',
#  'Bacteroides sp. 51': 'Bacteroidetes',
#  'Bacteroides sp. 224': 'Bacteroidetes',
#  'Bacteroides sp. 214': 'Bacteroidetes',
#  'Bacteroides sp. HF-5092': 'Bacteroidetes',
#  'Bacteroides sp. AF04-22': 'Bacteroidetes',
#  'Bacteroides sp. AM16-24': 'Bacteroidetes',
#  'Bacteroides sp. AF26-7BH': 'Bacteroidetes',
#  'Bacteroides sp. AF16-7': 'Bacteroidetes',
#  'Bacteroides sp. AF27-33': 'Bacteroidetes',
#  'Bacteroides sp. AF36-11BH': 'Bacteroidetes',
#  'Bacteroides sp. AF35-22': 'Bacteroidetes',
#  'Bacteroides sp. AF27-10BH': 'Bacteroidetes',
#  'Bacteroides sp. AM26-2': 'Bacteroidetes',
#  'Bacteroides sp. AM28-6': 'Bacteroidetes',
#  'Bacteroides xylanisolvens': 'Bacteroidetes',
#  'Bacteroides xylanisolvens CL03T12C04': 'Bacteroidetes',
#  'Bacteroides ndongoniae': 'Bacteroidetes',
#  'Bacteroides fragilis': 'Bacteroidetes',
#  'Bacteroides fragilis YCH46': 'Bacteroidetes',
#  'Bacteroides fragilis str. DS-208': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3976T8': 'Bacteroidetes',
#  'Bacteroides fragilis str. J-143-4': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3725 D9(v)': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3996 N(B) 6': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3998T(B)3': 'Bacteroidetes',
#  'Bacteroides fragilis str. S36L11': 'Bacteroidetes',
#  'Bacteroides fragilis str. S13 L11': 'Bacteroidetes',
#  'Bacteroides fragilis str. J38-1': 'Bacteroidetes',
#  'Bacteroides fragilis str. S6L3': 'Bacteroidetes',
#  'Bacteroides fragilis 3_1_12': 'Bacteroidetes',
#  'Bacteroides fragilis str. DS-71': 'Bacteroidetes',
#  'Bacteroides fragilis HMW 610': 'Bacteroidetes',
#  'Bacteroides fragilis str. A7 (UDC12-2)': 'Bacteroidetes',
#  'Bacteroides fragilis 638R': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3988T(B)14': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3783N1-6': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3988 T1': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3774 T13': 'Bacteroidetes',
#  'Bacteroides fragilis str. 3719 A10': 'Bacteroidetes',
#  'Bacteroides fragilis HMW 615': 'Bacteroidetes',
#  'Bacteroides dorei': 'Bacteroidetes',
#  'Bacteroides dorei DSM 17855': 'Bacteroidetes',
#  'Bacteroides dorei CL03T12C01': 'Bacteroidetes',
#  'Bacteroides dorei 5_1_36/D4': 'Bacteroidetes',
#  'Bacteroides mediterraneensis': 'Bacteroidetes',
#  'Bacteroides eggerthii': 'Bacteroidetes',
#  'Bacteroides eggerthii 1_2_48FAA': 'Bacteroidetes',
#  'Bacteroides faecis': 'Bacteroidetes',
#  'Bacteroides faecis MAJ27': 'Bacteroidetes',
#  'Bacteroides coprocola': 'Bacteroidetes',
#  'Bacteroides bouchesdurhonensis': 'Bacteroidetes',
#  'Bacteroides salanitronis': 'Bacteroidetes',
#  'Bacteroides salanitronis DSM 18170': 'Bacteroidetes',
#  'Bacteroides salyersiae': 'Bacteroidetes',
#  'Bacteroides salyersiae CL02T12C01': 'Bacteroidetes',
#  'Bacteroides salyersiae WAL 10018 = DSM 18765 = JCM 12988': 'Bacteroidetes',
#  'Bacteroides sartorii': 'Bacteroidetes',
#  'Bacteroides acidifaciens': 'Bacteroidetes',
#  'Bacteroides acidifaciens JCM 10556': 'Bacteroidetes',
#  'Bacteroides stercorirosoris': 'Bacteroidetes',
#  'Bacteroides nordii': 'Bacteroidetes',
#  'Bacteroides nordii CL02T12C05': 'Bacteroidetes',
#  'Bacteroides nordii WAL 11050 = JCM 12987': 'Bacteroidetes',
#  'Bacteroides ilei': 'Bacteroidetes',
#  'Bacteroides finegoldii': 'Bacteroidetes',
#  'Bacteroides finegoldii CL09T03C10': 'Bacteroidetes',
#  'Bacteroides finegoldii DSM 17565': 'Bacteroidetes',
#  'Bacteroides caecimuris': 'Bacteroidetes',
#  'Bacteroides intestinalis': 'Bacteroidetes',
#  'Bacteroides intestinalis DSM 17393': 'Bacteroidetes',
#  'Bacteroides cellulosilyticus': 'Bacteroidetes',
#  'Bacteroides cellulosilyticus CL02T12C19': 'Bacteroidetes',
#  'Bacteroides cellulosilyticus WH2': 'Bacteroidetes',
#  'Bacteroides clarus': 'Bacteroidetes',
#  'Bacteroides clarus YIT 12056': 'Bacteroidetes',
#  'Bacteroides togonis': 'Bacteroidetes',
#  'Bacteroides barnesiae': 'Bacteroidetes',
#  'Bacteroides barnesiae DSM 18169 = JCM 13652': 'Bacteroidetes',
#  'Bacteroides rodentium': 'Bacteroidetes',
#  'Bacteroides rodentium JCM 16496': 'Bacteroidetes',
#  'Bacteroides gallinarum': 'Bacteroidetes',
#  'Bacteroides gallinarum DSM 18171 = JCM 13658': 'Bacteroidetes',
#  'Bacteroides massiliensis': 'Bacteroidetes',
#  'Bacteroides massiliensis B84634 = Timone 84634 = DSM 17679 = JCM 13223': 'Bacteroidetes',
#  'Bacteroides faecichinchillae': 'Bacteroidetes',
#  'Bacteroides heparinolyticus': 'Bacteroidetes',
#  'Bacteroides pyogenes': 'Bacteroidetes',
#  'Bacteroides fluxus': 'Bacteroidetes',
#  'Bacteroides helcogenes': 'Bacteroidetes',
#  'Bacteroides helcogenes P 36-108': 'Bacteroidetes',
#  'Bacteroides congonensis': 'Bacteroidetes',
#  'Bacteroides graminisolvens': 'Bacteroidetes',
#  'Bacteroides graminisolvens DSM 19988 = JCM 15093': 'Bacteroidetes',
#  'Bacteroides caecimuri': 'Bacteroidetes',
#  'Bacteroides reticulotermitis': 'Bacteroidetes',
#  'Bacteroides reticulotermitis JCM 10512': 'Bacteroidetes',
#  'Bacteroides timonensis': 'Bacteroidetes',
#  'Bacteroides zoogleoformans': 'Bacteroidetes',
#  'Bacteroides neonati': 'Bacteroidetes',
#  'Bacteroides paurosaccharolyticus': 'Bacteroidetes',
#  'Bacteroides paurosaccharolyticus JCM 15092': 'Bacteroidetes',
#  'Bacteroides luti': 'Bacteroidetes',
#  'Bacteroides propionicifaciens': 'Bacteroidetes',
#  'Bacteroides propionicifaciens DSM 19291 = JCM 14649': 'Bacteroidetes',
#  'Bacteroides ihuae': 'Bacteroidetes',
#  'Bacteroides cutis': 'Bacteroidetes',
#  'Bacteroides xylanolyticus': 'Bacteroidetes',
#  'Bacteroides oleiciplenus': 'Bacteroidetes',
#  'unclassified Bacteroidaceae': 'Bacteroidetes',
#  'Bacteroidaceae bacterium': 'Bacteroidetes',
#  'Bacteroidaceae bacterium HV4-6-C5C': 'Bacteroidetes',
#  'Mediterranea': 'Bacteroidetes',
#  'Mediterranea massiliensis': 'Bacteroidetes',
#  'unclassified Mediterranea': 'Bacteroidetes',
#  'Mediterranea sp. An20': 'Bacteroidetes',
#  'Rikenellaceae': 'Bacteroidetes',
#  'Alistipes': 'Bacteroidetes',
#  'Alistipes putredinis': 'Bacteroidetes',
#  'Alistipes communis': 'Bacteroidetes',
#  'Alistipes shahii': 'Bacteroidetes',
#  'Alistipes shahii WAL 8301': 'Bacteroidetes',
#  'Alistipes ihumii': 'Bacteroidetes',
#  'unclassified Alistipes': 'Bacteroidetes',
#  'Alistipes sp. CHKCI003': 'Bacteroidetes',
#  'Alistipes sp. AF14-19': 'Bacteroidetes',
#  'Alistipes sp. AL-1': 'Bacteroidetes',
#  'Alistipes sp. An66': 'Bacteroidetes',
#  'Alistipes sp. An31A': 'Bacteroidetes',
#  'Alistipes sp. HGB5': 'Bacteroidetes',
#  'Alistipes sp. cv1': 'Bacteroidetes',
#  'Alistipes sp. AF48-12': 'Bacteroidetes',
#  'Alistipes sp. An54': 'Bacteroidetes',
#  'Alistipes sp. Marseille-P5061': 'Bacteroidetes',
#  'Alistipes sp. An116': 'Bacteroidetes',
#  'Alistipes sp. AM16-43': 'Bacteroidetes',
#  'Alistipes finegoldii': 'Bacteroidetes',
#  'Alistipes finegoldii DSM 17242': 'Bacteroidetes',
#  'Alistipes onderdonkii': 'Bacteroidetes',
#  'Alistipes onderdonkii WAL 8169 = DSM 19147': 'Bacteroidetes',
#  'Alistipes onderdonkii subsp. vulgaris': 'Bacteroidetes',
#  'Alistipes senegalensis': 'Bacteroidetes',
#  'Alistipes dispar': 'Bacteroidetes',
#  'Alistipes indistinctus': 'Bacteroidetes',
#  'Alistipes timonensis': 'Bacteroidetes',
#  'Alistipes megaguti': 'Bacteroidetes',
#  'unclassified Rikenellaceae': 'Bacteroidetes',
#  'Rikenellaceae bacterium': 'Bacteroidetes',
#  'Rikenella': 'Bacteroidetes',
#  'Rikenella microfusus': 'Bacteroidetes',
#  'Rikenella microfusus DSM 15922': 'Bacteroidetes',
#  'Millionella': 'Bacteroidetes',
#  'Millionella massiliensis': 'Bacteroidetes',
#  'Tannerellaceae': 'Bacteroidetes',
#  'Parabacteroides': 'Bacteroidetes',
#  'Parabacteroides merdae': 'Bacteroidetes',
#  'Parabacteroides merdae CL03T12C32': 'Bacteroidetes',
#  'Parabacteroides merdae CL09T00C40': 'Bacteroidetes',
#  'Parabacteroides merdae ATCC 43184': 'Bacteroidetes',
#  'Parabacteroides distasonis': 'Bacteroidetes',
#  'Parabacteroides distasonis ATCC 8503': 'Bacteroidetes',
#  'Parabacteroides distasonis str. 3999B T(B) 6': 'Bacteroidetes',
#  'Parabacteroides distasonis str. 3776 Po2 i': 'Bacteroidetes',
#  'Parabacteroides distasonis str. 3999B T(B) 4': 'Bacteroidetes',
#  'Parabacteroides distasonis CL09T03C24': 'Bacteroidetes',
#  'Parabacteroides distasonis str. 3776 D15 i': 'Bacteroidetes',
#  'Parabacteroides distasonis str. 3776 D15 iv': 'Bacteroidetes',
#  'unclassified Parabacteroides': 'Bacteroidetes',
#  'Parabacteroides sp. CT06': 'Bacteroidetes',
#  'Parabacteroides sp. D13': 'Bacteroidetes',
#  'Parabacteroides sp. 20_3': 'Bacteroidetes',
#  'Parabacteroides sp. AF19-14': 'Bacteroidetes',
#  'Parabacteroides sp. AM44-16': 'Bacteroidetes',
#  'Parabacteroides sp. An277': 'Bacteroidetes',
#  'Parabacteroides sp. AF39-10AC': 'Bacteroidetes',
#  'Parabacteroides sp. ZJ-118': 'Bacteroidetes',
#  'Parabacteroides sp. AF27-14': 'Bacteroidetes',
#  'Parabacteroides sp. HGS0025': 'Bacteroidetes',
#  'Parabacteroides sp. CH2-D42-20': 'Bacteroidetes',
#  'Parabacteroides sp. D26': 'Bacteroidetes',
#  'Parabacteroides sp. AF17-3': 'Bacteroidetes',
#  'Parabacteroides sp. AM58-2XD': 'Bacteroidetes',
#  'Parabacteroides sp. AM25-14': 'Bacteroidetes',
#  'Parabacteroides sp. AM18-12LB': 'Bacteroidetes',
#  'Parabacteroides sp. AF21-43': 'Bacteroidetes',
#  'Parabacteroides sp. AF14-59': 'Bacteroidetes',
#  'Parabacteroides sp. AF17-28': 'Bacteroidetes',
#  'Parabacteroides sp. OF01-14': 'Bacteroidetes',
#  'Parabacteroides sp. Marseille-P3160': 'Bacteroidetes',
#  'Parabacteroides johnsonii': 'Bacteroidetes',
#  'Parabacteroides johnsonii DSM 18315': 'Bacteroidetes',
#  'Parabacteroides johnsonii CL02T12C29': 'Bacteroidetes',
#  'Parabacteroides goldsteinii': 'Bacteroidetes',
#  'Parabacteroides goldsteinii DSM 19448 = WAL 12034': 'Bacteroidetes',
#  'Parabacteroides goldsteinii CL02T12C30': 'Bacteroidetes',
#  'Parabacteroides massiliensis': 'Bacteroidetes',
#  'Parabacteroides chinchillae': 'Bacteroidetes',
#  'Parabacteroides timonensis': 'Bacteroidetes',
#  'Parabacteroides bouchesdurhonensis': 'Bacteroidetes',
#  'Parabacteroides pacaensis': 'Bacteroidetes',
#  'Tannerella': 'Bacteroidetes',
#  'Tannerella forsythia': 'Bacteroidetes',
#  'Tannerella forsythia 92A2': 'Bacteroidetes',
#  'unclassified Tannerella': 'Bacteroidetes',
#  'Tannerella sp. oral taxon HOT-286': 'Bacteroidetes',
#  'Odoribacteraceae': 'Bacteroidetes',
#  'Odoribacter': 'Bacteroidetes',
#  'Odoribacter splanchnicus': 'Bacteroidetes',
#  'unclassified Odoribacter': 'Bacteroidetes',
#  'Odoribacter sp. AM16-33': 'Bacteroidetes',
#  'Odoribacter laneus': 'Bacteroidetes',
#  'Butyricimonas': 'Bacteroidetes',
#  'Butyricimonas virosa': 'Bacteroidetes',
#  'Butyricimonas virosa DSM 23226': 'Bacteroidetes',
#  'Butyricimonas faecihominis': 'Bacteroidetes',
#  'Butyricimonas faecalis': 'Bacteroidetes',
#  'unclassified Butyricimonas': 'Bacteroidetes',
#  'Butyricimonas sp. An62': 'Bacteroidetes',
#  'Butyricimonas sp. Marseille-P4593': 'Bacteroidetes',
#  'Butyricimonas sp. Marseille-P3923': 'Bacteroidetes',
#  'Butyricimonas paravirosa': 'Bacteroidetes',
#  'Butyricimonas synergistica': 'Bacteroidetes',
#  'Butyricimonas synergistica DSM 23225': 'Bacteroidetes',
#  'Culturomica': 'Bacteroidetes',
#  'Culturomica massiliensis': 'Bacteroidetes',
#  'Barnesiellaceae': 'Bacteroidetes',
#  'Barnesiella': 'Bacteroidetes',
#  'Barnesiella intestinihominis': 'Bacteroidetes',
#  'Barnesiella intestinihominis YIT 11860': 'Bacteroidetes',
#  'Barnesiella viscericola': 'Bacteroidetes',
#  'Barnesiella viscericola DSM 18177': 'Bacteroidetes',
#  'unclassified Barnesiella': 'Bacteroidetes',
#  'Barnesiella sp. An22': 'Bacteroidetes',
#  'Barnesiella sp. An55': 'Bacteroidetes',
#  'Barnesiella sp. WM24': 'Bacteroidetes',
#  'Coprobacter': 'Bacteroidetes',
#  'Coprobacter fastidiosus': 'Bacteroidetes',
#  'Coprobacter fastidiosus NSB1': 'Bacteroidetes',
#  'Porphyromonadaceae': 'Bacteroidetes',
#  'Porphyromonas': 'Bacteroidetes',
#  'Porphyromonas bennonis': 'Bacteroidetes',
#  'Porphyromonas bennonis DSM 23058 = JCM 16335': 'Bacteroidetes',
#  'Porphyromonas asaccharolytica': 'Bacteroidetes',
#  'Porphyromonas asaccharolytica PR426713P-I': 'Bacteroidetes',
#  'Porphyromonas asaccharolytica DSM 20707': 'Bacteroidetes',
#  'Porphyromonas uenonis': 'Bacteroidetes',
#  'Porphyromonas uenonis DSM 23387 = JCM 13868': 'Bacteroidetes',
#  'Porphyromonas uenonis 60-3': 'Bacteroidetes',
#  'unclassified Porphyromonas': 'Bacteroidetes',
#  'Porphyromonas sp. HMSC077F02': 'Bacteroidetes',
#  'Porphyromonas sp. HMSC065F10': 'Bacteroidetes',
#  'Porphyromonas somerae': 'Bacteroidetes',
#  'Porphyromonas somerae DSM 23386': 'Bacteroidetes',
#  'Porphyromonas levii': 'Bacteroidetes',
#  'Porphyromonas levii DSM 23370': 'Bacteroidetes',
#  'Porphyromonas gingivalis': 'Bacteroidetes',
#  'Porphyromonas endodontalis': 'Bacteroidetes',
#  'Porphyromonas loveana': 'Bacteroidetes',
#  'Porphyromonas canoris': 'Bacteroidetes',
#  'Porphyromonas catoniae': 'Bacteroidetes',
#  'Porphyromonas catoniae ATCC 51270': 'Bacteroidetes',
#  'Porphyromonas crevioricanis': 'Bacteroidetes',
#  'Porphyromonas macacae': 'Bacteroidetes',
#  'Sanguibacteroides': 'Bacteroidetes',
#  'Sanguibacteroides justesenii': 'Bacteroidetes',
#  'unclassified Porphyromonadaceae': 'Bacteroidetes',
#  'Porphyromonadaceae bacterium FC4': 'Bacteroidetes',
#  'Porphyromonadaceae bacterium H1': 'Bacteroidetes',
#  'Porphyromonadaceae bacterium': 'Bacteroidetes',
#  'unclassified Bacteroidales': 'Bacteroidetes',
#  'unclassified Bacteroidales (miscellaneous)': 'Bacteroidetes',
#  'Bacteroidales bacterium': 'Bacteroidetes',
#  'Bacteroidales bacterium KHT7': 'Bacteroidetes',
#  'Bacteroidales bacterium KA00251': 'Bacteroidetes',
#  'Bacteroidales bacterium KA00344': 'Bacteroidetes',
#  'Bacteroidales bacterium WCE2008': 'Bacteroidetes',
#  'Bacteroidales bacterium WCE2004': 'Bacteroidetes',
#  'Bacteroidales bacterium CF': 'Bacteroidetes',
#  'Bacteroidales bacterium Barb4': 'Bacteroidetes',
#  'Bacteroidales bacterium Barb6XT': 'Bacteroidetes',
#  'Phocaeicola': 'Bacteroidetes',
#  'Phocaeicola abscessus': 'Bacteroidetes',
#  'Phocaeicola abscessus CCUG 55929': 'Bacteroidetes',
#  'Candidatus Symbiothrix': 'Bacteroidetes',
#  'Candidatus Symbiothrix dinenymphae': 'Bacteroidetes',
#  'Muribaculaceae': 'Bacteroidetes',
#  'Muribaculum': 'Bacteroidetes',
#  'unclassified Muribaculum': 'Bacteroidetes',
#  'Muribaculum intestinale': 'Bacteroidetes',
#  'unclassified Muribaculaceae': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-002 (NCI)': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-110 (HZI)': 'Bacteroidetes',
#  'Muribaculaceae bacterium': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-105 (HZI)': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-013 (NCI)': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-007 (NCI)': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-004 (NCI)': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-039 (Harlan)': 'Bacteroidetes',
#  'Muribaculaceae bacterium Isolate-080 (Janvier)': 'Bacteroidetes',
#  'Duncaniella': 'Bacteroidetes',
#  'Duncaniella muris': 'Bacteroidetes',
#  'Dysgonamonadaceae': 'Bacteroidetes',
#  'Proteiniphilum': 'Bacteroidetes',
#  'unclassified Proteiniphilum': 'Bacteroidetes',
#  'Proteiniphilum sp. X52': 'Bacteroidetes',
#  'Dysgonomonas': 'Bacteroidetes',
#  'unclassified Dysgonomonas': 'Bacteroidetes',
#  'Dysgonomonas sp. 25': 'Bacteroidetes',
#  'Dysgonomonas sp. 216': 'Bacteroidetes',
#  'Dysgonomonas sp. 521': 'Bacteroidetes',
#  'Dysgonomonas macrotermitis': 'Bacteroidetes',
#  'Dysgonomonas capnocytophagoides': 'Bacteroidetes',
#  'Dysgonomonas capnocytophagoides DSM 22835': 'Bacteroidetes',
#  'Dysgonomonas gadei': 'Bacteroidetes',
#  'Dysgonomonas massiliensis': 'Bacteroidetes',
#  'Paludibacteraceae': 'Bacteroidetes',
#  'Paludibacter': 'Bacteroidetes',
#  'Paludibacter jiangxiensis': 'Bacteroidetes',
#  'Williamwhitmaniaceae': 'Bacteroidetes',
#  'Williamwhitmania': 'Bacteroidetes',
#  'Williamwhitmania taraxaci': 'Bacteroidetes',
#  'Marinilabiliales': 'Bacteroidetes',
#  'Prolixibacteraceae': 'Bacteroidetes',
#  'Mangrovibacterium': 'Bacteroidetes',
#  'Mangrovibacterium marinum': 'Bacteroidetes',
#  'unclassified Mangrovibacterium': 'Bacteroidetes',
#  'Mangrovibacterium sp. BM_7': 'Bacteroidetes',
#  'Puteibacter': 'Bacteroidetes',
#  'Puteibacter caeruleilacunae': 'Bacteroidetes',
#  'unclassified Prolixibacteraceae': 'Bacteroidetes',
#  'Prolixibacteraceae bacterium WC007': 'Bacteroidetes',
#  'Prolixibacter': 'Bacteroidetes',
#  'Prolixibacter bellariivorans': 'Bacteroidetes',
#  'Tangfeifania': 'Bacteroidetes',
#  'Tangfeifania diversioriginum': 'Bacteroidetes',
#  'Maribellus': 'Bacteroidetes',
#  'Maribellus luteus': 'Bacteroidetes',
#  'Marinilabiliaceae': 'Bacteroidetes',
#  'Natronoflexus': 'Bacteroidetes',
#  'Natronoflexus pectinivorans': 'Bacteroidetes',
#  'Labilibacter': 'Bacteroidetes',
#  'Labilibacter sediminis': 'Bacteroidetes',
#  'Anaerophaga': 'Bacteroidetes',
#  'Anaerophaga thermohalophila': 'Bacteroidetes',
#  'Anaerophaga thermohalophila DSM 12881': 'Bacteroidetes',
#  'Geofilum': 'Bacteroidetes',
#  'Geofilum rubicundum': 'Bacteroidetes',
#  'Geofilum rubicundum JCM 15548': 'Bacteroidetes',
#  'Marinifilaceae': 'Bacteroidetes',
#  'Ancylomarina': 'Bacteroidetes',
#  'Chitinophagia': 'Bacteroidetes',
#  'Chitinophagales': 'Bacteroidetes',
#  'Chitinophagaceae': 'Bacteroidetes',
#  'Chitinophaga': 'Bacteroidetes',
#  'unclassified Chitinophaga': 'Bacteroidetes',
#  'Chitinophaga sp. K20C18050901': 'Bacteroidetes',
#  'Chitinophaga sp. MD30': 'Bacteroidetes',
#  'Chitinophaga sp. S165': 'Bacteroidetes',
#  'Chitinophaga sp. SYP-B3965': 'Bacteroidetes',
#  'Chitinophaga sp. BN140078': 'Bacteroidetes',
#  '[Flexibacter] sp. ATCC 35208': 'Bacteroidetes',
#  'Chitinophaga pinensis': 'Bacteroidetes',
#  'Chitinophaga varians': 'Bacteroidetes',
#  'Chitinophaga costaii': 'Bacteroidetes',
#  'Asinibacterium': 'Bacteroidetes',
#  'unclassified Asinibacterium': 'Bacteroidetes',
#  'Asinibacterium sp. OR53': 'Bacteroidetes',
#  'Filimonas': 'Bacteroidetes',
#  'unclassified Filimonas': 'Bacteroidetes',
#  'Filimonas sp. YR581': 'Bacteroidetes',
#  'Paraflavitalea': 'Bacteroidetes',
#  'Paraflavitalea soli': 'Bacteroidetes',
#  'Taibaiella': 'Bacteroidetes',
#  'Hydrotalea': 'Bacteroidetes',
#  'Hydrotalea flava': 'Bacteroidetes',
#  'Lacibacter': 'Bacteroidetes',
#  'Lacibacter cauensis': 'Bacteroidetes',
#  'Flavobacteriia': 'Bacteroidetes',
#  'Flavobacteriales': 'Bacteroidetes',
#  'Flavobacteriaceae': 'Bacteroidetes',
#  'Chryseobacterium': 'Bacteroidetes',
#  'Chryseobacterium oncorhynchi': 'Bacteroidetes',
#  'Chryseobacterium haifense': 'Bacteroidetes',
#  'unclassified Chryseobacterium': 'Bacteroidetes',
#  'Chryseobacterium sp. ISE14': 'Bacteroidetes',
#  'Chryseobacterium camelliae': 'Bacteroidetes',
#  'Chryseobacterium viscerum': 'Bacteroidetes',
#  'Flavobacterium': 'Bacteroidetes',
#  'unclassified Flavobacterium': 'Bacteroidetes',
#  'Flavobacterium sp. xlx-214': 'Bacteroidetes',
#  'Flavobacterium sp. WG21': 'Bacteroidetes',
#  'Flavobacterium sp. LaA7.5': 'Bacteroidetes',
#  'Flavobacterium microcysteis': 'Bacteroidetes',
#  'Flavobacterium araucananum': 'Bacteroidetes',
#  'Flavobacterium anhuiense': 'Bacteroidetes',
#  'Flavobacterium croceum': 'Bacteroidetes',
#  'Flavobacterium croceum DSM 17960': 'Bacteroidetes',
#  'Flavobacterium degerlachei': 'Bacteroidetes',
#  'Flavobacterium limicola': 'Bacteroidetes',
#  'Flavobacterium silvisoli': 'Bacteroidetes',
#  'Capnocytophaga': 'Bacteroidetes',
#  'unclassified Capnocytophaga': 'Bacteroidetes',
#  'Capnocytophaga sp. oral taxon 329': 'Bacteroidetes',
#  'Capnocytophaga sp. oral taxon 329 str. F0087': 'Bacteroidetes',
#  'Capnocytophaga granulosa': 'Bacteroidetes',
#  'Capnocytophaga haemolytica': 'Bacteroidetes',
#  'Ornithobacterium': 'Bacteroidetes',
#  'Ornithobacterium rhinotracheale': 'Bacteroidetes',
#  'Gramella': 'Bacteroidetes',
#  'Gramella flava': 'Bacteroidetes',
#  'Gramella flava JLT2011': 'Bacteroidetes',
#  'Gramella salexigens': 'Bacteroidetes',
#  'Muricauda': 'Bacteroidetes',
#  'Muricauda beolgyonensis': 'Bacteroidetes',
#  'Tamlana': 'Bacteroidetes',
#  'Tamlana crocina': 'Bacteroidetes',
#  'unclassified Tamlana': 'Bacteroidetes',
#  'Tamlana sp. UJ94': 'Bacteroidetes',
#  'Aquimarina': 'Bacteroidetes',
#  'unclassified Aquimarina': 'Bacteroidetes',
#  'Aquimarina sp. Aq135': 'Bacteroidetes',
#  'Aquimarina aggregata': 'Bacteroidetes',
#  'Aquimarina amphilecti': 'Bacteroidetes',
#  'Myroides': 'Bacteroidetes',
#  'Myroides marinus': 'Bacteroidetes',
#  'Myroides odoratus': 'Bacteroidetes',
#  'Myroides guanonis': 'Bacteroidetes',
#  'Mangrovimonas': 'Bacteroidetes',
#  'unclassified Mangrovimonas': 'Bacteroidetes',
#  'Mangrovimonas sp. TPBH4': 'Bacteroidetes',
#  'Mangrovimonas sp. CR14': 'Bacteroidetes',
#  'unclassified Flavobacteriaceae': 'Bacteroidetes',
#  'Flavobacteriaceae bacterium 3519-10': 'Bacteroidetes',
#  'Flavobacteriaceae bacterium TP-CH-4': 'Bacteroidetes',
#  'Flagellimonas': 'Bacteroidetes',
#  'Flagellimonas maritima': 'Bacteroidetes',
#  'unclassified Flagellimonas': 'Bacteroidetes',
#  'Flagellimonas sp. 176CP5-101': 'Bacteroidetes',
#  'Apibacter': 'Bacteroidetes',
#  'unclassified Apibacter': 'Bacteroidetes',
#  'Apibacter sp. B2912': 'Bacteroidetes',
#  'Salegentibacter': 'Bacteroidetes',
#  'Salegentibacter sediminis': 'Bacteroidetes',
#  'Elizabethkingia': 'Bacteroidetes',
#  'Elizabethkingia argentiflava': 'Bacteroidetes',
#  'Psychroflexus': 'Bacteroidetes',
#  'Psychroflexus tropicus': 'Bacteroidetes',
#  'Psychroflexus tropicus DSM 15496': 'Bacteroidetes',
#  'Nonlabens': 'Bacteroidetes',
#  'Lutibacter': 'Bacteroidetes',
#  'unclassified Lutibacter': 'Bacteroidetes',
#  'Lutibacter sp. 1KV19': 'Bacteroidetes',
#  'Riemerella': 'Bacteroidetes',
#  'Riemerella anatipestifer': 'Bacteroidetes',
#  'Bergeyella': 'Bacteroidetes',
#  'Bergeyella cardium': 'Bacteroidetes',
#  'Marinirhabdus': 'Bacteroidetes',
#  'Marinirhabdus gelatinilytica': 'Bacteroidetes',
#  'Imtechella': 'Bacteroidetes',
#  'Imtechella halotolerans': 'Bacteroidetes',
#  'Imtechella halotolerans K1': 'Bacteroidetes',
#  'Mariniflexile': 'Bacteroidetes',
#  'unclassified Mariniflexile': 'Bacteroidetes',
#  'Mariniflexile sp. TRM1-10': 'Bacteroidetes',
#  'Salinimicrobium': 'Bacteroidetes',
#  'Salinimicrobium xinjiangense': 'Bacteroidetes',
#  'Salinimicrobium xinjiangense DSM 19287': 'Bacteroidetes',
#  'Gelidibacter': 'Bacteroidetes',
#  'Gelidibacter gilvus': 'Bacteroidetes',
#  'Olleya': 'Bacteroidetes',
#  'Algoriella': 'Bacteroidetes',
#  'Algoriella xinjiangensis': 'Bacteroidetes',
#  'Algibacter': 'Bacteroidetes',
#  'Algibacter alginicilyticus': 'Bacteroidetes',
#  'Maribacter': 'Bacteroidetes',
#  'unclassified Maribacter': 'Bacteroidetes',
#  'Maribacter sp. HTCC2170': 'Bacteroidetes',
#  'Sinomicrobium': 'Bacteroidetes',
#  'Sinomicrobium oceani': 'Bacteroidetes',
#  'Formosa': 'Bacteroidetes',
#  'Formosa agariphila': 'Bacteroidetes',
#  'Formosa agariphila KMM 3901': 'Bacteroidetes',
#  'Arenibacter': 'Bacteroidetes',
#  'Arenibacter palladensis': 'Bacteroidetes',
#  'Aequorivita': 'Bacteroidetes',
#  'unclassified Aequorivita': 'Bacteroidetes',
#  'Aequorivita sp. CIP111184': 'Bacteroidetes',
#  'Zobellia': 'Bacteroidetes',
#  'Zobellia uliginosa': 'Bacteroidetes',
#  'Flavivirga': 'Bacteroidetes',
#  'Flavivirga rizhaonensis': 'Bacteroidetes',
#  'Tenacibaculum': 'Bacteroidetes',
#  'Tenacibaculum todarodis': 'Bacteroidetes',
#  'Cellulophaga': 'Bacteroidetes',
#  'Empedobacter': 'Bacteroidetes',
#  'unclassified Empedobacter': 'Bacteroidetes',
#  'Empedobacter sp. MRS2': 'Bacteroidetes',
#  'unclassified Flavobacteriales': 'Bacteroidetes',
#  'Candidatus Sulcia': 'Bacteroidetes',
#  'Candidatus Sulcia muelleri': 'Bacteroidetes',
#  'unclassified Flavobacteriales (miscellaneous)': 'Bacteroidetes',
#  'Flavobacteriales bacterium ALC-1': 'Bacteroidetes',
#  'Blattabacteriaceae': 'Bacteroidetes',
#  'Blattabacterium': 'Bacteroidetes',
#  'Cytophagia': 'Bacteroidetes',
#  'Cytophagales': 'Bacteroidetes',
#  'Hymenobacteraceae': 'Bacteroidetes',
#  'Hymenobacter': 'Bacteroidetes',
#  'Hymenobacter terrenus': 'Bacteroidetes',
#  'unclassified Hymenobacter': 'Bacteroidetes',
#  'Hymenobacter sp. DG01': 'Bacteroidetes',
#  'Hymenobacter lapidarius': 'Bacteroidetes',
#  'Pontibacter': 'Bacteroidetes',
#  'unclassified Pontibacter': 'Bacteroidetes',
#  'Pontibacter sp. BT214': 'Bacteroidetes',
#  'Pontibacter roseus': 'Bacteroidetes',
#  'Pontibacter roseus DSM 17521': 'Bacteroidetes',
#  'Rufibacter': 'Bacteroidetes',
#  'unclassified Rufibacter': 'Bacteroidetes',
#  'Rufibacter sp. DG31D': 'Bacteroidetes',
#  'Cytophagaceae': 'Bacteroidetes',
#  'Spirosoma': 'Bacteroidetes',
#  'Spirosoma pollinicola': 'Bacteroidetes',
#  'Spirosoma spitsbergense': 'Bacteroidetes',
#  'Spirosoma spitsbergense DSM 19989': 'Bacteroidetes',
#  'Flectobacillus': 'Bacteroidetes',
#  'Flectobacillus major': 'Bacteroidetes',
#  'Flectobacillus major DSM 103': 'Bacteroidetes',
#  'Runella': 'Bacteroidetes',
#  'Ohtaekwangia': 'Bacteroidetes',
#  'Ohtaekwangia koreensis': 'Bacteroidetes',
#  'Dyadobacter': 'Bacteroidetes',
#  'Dyadobacter jejuensis': 'Bacteroidetes',
#  'Emticicia': 'Bacteroidetes',
#  'unclassified Emticicia': 'Bacteroidetes',
#  'Emticicia sp. ODNR4P': 'Bacteroidetes',
#  'Cyclobacteriaceae': 'Bacteroidetes',
#  'Algoriphagus': 'Bacteroidetes',
#  'Algoriphagus kandeliae': 'Bacteroidetes',
#  'Algoriphagus lacus': 'Bacteroidetes',
#  'Algoriphagus sanaruensis': 'Bacteroidetes',
#  'Algoriphagus terrigena': 'Bacteroidetes',
#  'Algoriphagus terrigena DSM 22685': 'Bacteroidetes',
#  'Lunatimonas': 'Bacteroidetes',
#  'Lunatimonas lonarensis': 'Bacteroidetes',
#  'Cyclobacterium': 'Bacteroidetes',
#  'unclassified Cyclobacterium': 'Bacteroidetes',
#  'Cyclobacterium sp. GBPx2': 'Bacteroidetes',
#  'unclassified Cyclobacteriaceae': 'Bacteroidetes',
#  'Cyclobacteriaceae bacterium CUG 91308': 'Bacteroidetes',
#  'unclassified Cytophagales': 'Bacteroidetes',
#  'Chryseolinea': 'Bacteroidetes',
#  'Chryseolinea serpens': 'Bacteroidetes',
#  'Flammeovirgaceae': 'Bacteroidetes',
#  'Reichenbachiella': 'Bacteroidetes',
#  'Amoebophilaceae': 'Bacteroidetes',
#  'Candidatus Amoebophilus': 'Bacteroidetes',
#  'Candidatus Amoebophilus asiaticus': 'Bacteroidetes',
#  'Candidatus Amoebophilus asiaticus 5a2': 'Bacteroidetes',
#  'Candidatus Cardinium': 'Bacteroidetes',
#  'Sphingobacteriia': 'Bacteroidetes',
#  'Sphingobacteriales': 'Bacteroidetes',
#  'Sphingobacteriaceae': 'Bacteroidetes',
#  'Sphingobacterium': 'Bacteroidetes',
#  'Sphingobacterium gobiense': 'Bacteroidetes',
#  'unclassified Sphingobacterium': 'Bacteroidetes',
#  'Sphingobacterium sp. Ag1': 'Bacteroidetes',
#  'Sphingobacterium deserti': 'Bacteroidetes',
#  'Sphingobacterium alimentarium': 'Bacteroidetes',
#  'Sphingobacterium psychroaquaticum': 'Bacteroidetes',
#  'Sphingobacterium mizutaii': 'Bacteroidetes',
#  'Pedobacter': 'Bacteroidetes',
#  'unclassified Pedobacter': 'Bacteroidetes',
#  'Pedobacter sp. L105': 'Bacteroidetes',
#  'Pedobacter psychrotolerans': 'Bacteroidetes',
#  'Pedobacter glucosidilyticus': 'Bacteroidetes',
#  'Pedobacter glucosidilyticus DSM 23534': 'Bacteroidetes',
#  'Pedobacter oryzae': 'Bacteroidetes',
#  'Pedobacter oryzae DSM 19973': 'Bacteroidetes',
#  'Pedobacter caeni': 'Bacteroidetes',
#  'Mucilaginibacter': 'Bacteroidetes',
#  'unclassified Mucilaginibacter': 'Bacteroidetes',
#  'Mucilaginibacter sp. HME9299': 'Bacteroidetes',
#  'Mucilaginibacter sp. HC2': 'Bacteroidetes',
#  'Mucilaginibacter sp. OK283': 'Bacteroidetes',
#  'Mucilaginibacter hurinus': 'Bacteroidetes',
#  'Mucilaginibacter ginsenosidivorax': 'Bacteroidetes',
#  'Pelobium': 'Bacteroidetes',
#  'Pelobium manganitolerans': 'Bacteroidetes',
#  'Bacteroidetes Order II. Incertae sedis': 'Bacteroidetes',
#  'Rhodothermaceae': 'Bacteroidetes',
#  'Rhodothermus': 'Bacteroidetes',
#  'Rhodothermus marinus': 'Bacteroidetes',
#  'Salinibacter': 'Bacteroidetes',
#  'Salinibacter altiplanensis': 'Bacteroidetes',
#  'Saprospiria': 'Bacteroidetes',
#  'Saprospirales': 'Bacteroidetes',
#  'Lewinellaceae': 'Bacteroidetes',
#  'Lewinella': 'Bacteroidetes',
#  'Lewinella nigricans': 'Bacteroidetes',
#  'Lewinella nigricans DSM 23189 = NBRC 102662': 'Bacteroidetes',
#  'Lewinella antarctica': 'Bacteroidetes',
#  'unclassified Lewinella': 'Bacteroidetes',
#  'Lewinella sp. IMCC34183': 'Bacteroidetes',
#  'Haliscomenobacteraceae': 'Bacteroidetes',
#  'Phaeodactylibacter': 'Bacteroidetes',
#  'Phaeodactylibacter luteus': 'Bacteroidetes',
#  'Chlorobi': 'Chlorobi',
#  'Chlorobia': 'Chlorobi',
#  'Chlorobiales': 'Chlorobi',
#  'Chlorobiaceae': 'Chlorobi',
#  'Chlorobaculum': 'Chlorobi',
#  'unclassified Chlorobaculum': 'Chlorobi',
#  'Chlorobaculum sp. 24CR': 'Chlorobi',
#  'Chlorobium/Pelodictyon group': 'Chlorobi',
#  'Chlorobium': 'Chlorobi',
#  'unclassified Chlorobium': 'Chlorobi',
#  'Chlorobium sp. N1': 'Chlorobi',
#  'Rhodothermaeota': 'Rhodothermaeota',
#  'Rhodothermia': 'Rhodothermaeota',
#  'Rhodothermales': 'Rhodothermaeota',
#  'Rubricoccaceae': 'Rhodothermaeota',
#  'Rubrivirga': 'Rhodothermaeota',
#  'unclassified Rubrivirga': 'Rhodothermaeota',
#  'Rubrivirga sp. SAORIC476': 'Rhodothermaeota',
#  'Fibrobacteria': 'Fibrobacteria',
#  'Fibrobacterales': 'Fibrobacteria',
#  'Fibrobacteraceae': 'Fibrobacteria',
#  'Fibrobacter': 'Fibrobacteria',
#  'unclassified Fibrobacter': 'Fibrobacteria',
#  'Fibrobacter sp. UWEL': 'Fibrobacteria',
#  'Fibrobacter sp. UWP2': 'Fibrobacteria',
#  'Fibrobacter succinogenes': 'Fibrobacteria',
#  'Chitinivibrionia': 'Chitinivibrionia',
#  'Chitinivibrionales': 'Chitinivibrionia',
#  'Chitinivibrionaceae': 'Chitinivibrionia',
#  'Chitinivibrio': 'Chitinivibrionia',
#  'Chitinivibrio alkaliphilus': 'Chitinivibrionia',
#  'Chitinivibrio alkaliphilus ACht1': 'Chitinivibrionia',
#  'Clostridia': 'Clostridia',
#  'Clostridiales': 'Clostridia',
#  'Lachnospiraceae': 'Clostridia',
#  'unclassified Lachnospiraceae': 'Clostridia',
#  '[Eubacterium] rectale': 'Clostridia',
#  'Lachnospiraceae bacterium': 'Clostridia',
#  'Lachnospiraceae bacterium BSM-380-WT-5A': 'Clostridia',
#  'Lachnospiraceae bacterium OF11-28': 'Clostridia',
#  'Lachnospiraceae bacterium 7_1_58FAA': 'Clostridia',
#  'Lachnospiraceae bacterium MD329': 'Clostridia',
#  'Lachnospiraceae bacterium KGMB03038': 'Clostridia',
#  'Lachnospiraceae bacterium WCA3-601-WT-6H': 'Clostridia',
#  'Lachnospiraceae bacterium Choco86': 'Clostridia',
#  'Lachnospiraceae bacterium GAM79': 'Clostridia',
#  'Lachnospiraceae bacterium AM26-1LB': 'Clostridia',
#  'Lachnospiraceae bacterium 10-1': 'Clostridia',
#  'Lachnospiraceae bacterium 5_1_63FAA': 'Clostridia',
#  'Lachnospiraceae bacterium 9_1_43BFAA': 'Clostridia',
#  'Lachnospiraceae bacterium AM21-21': 'Clostridia',
#  'Lachnospiraceae bacterium 6_1_37FAA': 'Clostridia',
#  'Lachnospiraceae bacterium AM10-38': 'Clostridia',
#  'Lachnospiraceae bacterium 3_1_57FAA_CT1': 'Clostridia',
#  'Lachnospiraceae bacterium 3-1': 'Clostridia',
#  'Lachnospiraceae bacterium Oil+RF-744-WCA-WT-11': 'Clostridia',
#  'Lachnospiraceae bacterium AM25-27': 'Clostridia',
#  'Lachnospiraceae bacterium OM02-26': 'Clostridia',
#  'Lachnospiraceae bacterium TF10-8AT': 'Clostridia',
#  'Lachnospiraceae bacterium oral taxon 096': 'Clostridia',
#  'Lachnospiraceae bacterium AM40-2BH': 'Clostridia',
#  'Lachnospiraceae bacterium Oil+RF-744-WCA-WT-13': 'Clostridia',
#  'Lachnospiraceae bacterium MD335': 'Clostridia',
#  'Lachnospiraceae bacterium oral taxon 500': 'Clostridia',
#  'Lachnospiraceae oral taxon 107 str. F0167': 'Clostridia',
#  'Lachnospiraceae bacterium KM106-2': 'Clostridia',
#  'Lachnospiraceae bacterium MD308': 'Clostridia',
#  'Lachnospiraceae bacterium WCA-693-APC-MOT-I': 'Clostridia',
#  'Lachnospiraceae bacterium NC2004': 'Clostridia',
#  'Lachnospiraceae bacterium WCA-9-b2': 'Clostridia',
#  'Lachnospiraceae bacterium TF09-5': 'Clostridia',
#  'Lachnospiraceae bacterium 6_1_63FAA': 'Clostridia',
#  'Lachnospiraceae bacterium G11': 'Clostridia',
#  'Lachnospiraceae bacterium AM23-7LB': 'Clostridia',
#  'Lachnospiraceae bacterium Marseille-P3773': 'Clostridia',
#  'Lachnospiraceae bacterium NK3A20': 'Clostridia',
#  'Lachnospiraceae bacterium A4': 'Clostridia',
#  'Lachnospiraceae bacterium A2': 'Clostridia',
#  'Lachnospiraceae bacterium AC2014': 'Clostridia',
#  'Lachnospiraceae bacterium ND2006': 'Clostridia',
#  'Lachnospiraceae bacterium 5_1_57FAA': 'Clostridia',
#  'Lachnospiraceae bacterium AM25-17': 'Clostridia',
#  'Lachnospiraceae bacterium TM07-2AC': 'Clostridia',
#  'Lachnospiraceae bacterium C7': 'Clostridia',
#  'Lachnospiraceae bacterium VE202-12': 'Clostridia',
#  'Lachnospiraceae bacterium RM5': 'Clostridia',
#  'Lachnospiraceae bacterium MC2017': 'Clostridia',
#  'Lachnospiraceae bacterium TWA4': 'Clostridia',
#  'Lachnospiraceae bacterium AC2012': 'Clostridia',
#  'Lachnospiraceae bacterium AM23-2LB': 'Clostridia',
#  'Lachnospiraceae bacterium JC7': 'Clostridia',
#  'Lachnospiraceae bacterium oral taxon 082': 'Clostridia',
#  'Lachnospiraceae bacterium oral taxon 082 str. F0431': 'Clostridia',
#  'Lachnospiraceae bacterium KHCPX20': 'Clostridia',
#  'Lachnospiraceae bacterium AC2029': 'Clostridia',
#  'Lachnospiraceae bacterium XBD2001': 'Clostridia',
#  'Lachnospiraceae bacterium P6B14': 'Clostridia',
#  'Lachnospiraceae bacterium AD3010': 'Clostridia',
#  'Lachnospiraceae bacterium A10': 'Clostridia',
#  'Lachnospiraceae bacterium YSB2008': 'Clostridia',
#  'Lachnospiraceae bacterium NLAE-zl-G231': 'Clostridia',
#  'Lachnospiraceae bacterium C6A11': 'Clostridia',
#  'Lachnospiraceae bacterium NK4A179': 'Clostridia',
#  'Lachnospiraceae bacterium MA2020': 'Clostridia',
#  'Lachnospiraceae bacterium AC3007': 'Clostridia',
#  'Lachnospiraceae bacterium FE2018': 'Clostridia',
#  'Lachnospiraceae bacterium P6A3': 'Clostridia',
#  'Lachnospiraceae bacterium V9D3004': 'Clostridia',
#  'Lachnospiraceae bacterium KH1T2': 'Clostridia',
#  'Lachnospiraceae bacterium AC2031': 'Clostridia',
#  'Lachnospiraceae bacterium M18-1': 'Clostridia',
#  'Lachnospiraceae bacterium XBB2008': 'Clostridia',
#  'Lachnospiraceae bacterium G41': 'Clostridia',
#  'Dorea': 'Clostridia',
#  'Dorea longicatena': 'Clostridia',
#  'Dorea longicatena DSM 13814': 'Clostridia',
#  'Dorea longicatena AGR2136': 'Clostridia',
#  'Dorea formicigenerans': 'Clostridia',
#  'Dorea formicigenerans ATCC 27755': 'Clostridia',
#  ...}

# %%
# trim down to a specific level for visualization purposes
if run_trimmed:
    target_level = 5

    kraken_tmp = {}

    for s, sv in kraken_data.items():
        if "_dm" in s:
            kraken_tmp[s] = kraken_data[s]
        else:
            kraken_tmp[s] = {}

            for k, v in sv.items():
                tmp_k = k.split("\t")

                if tmp_k[target_level] != "-" and tmp_k[target_level+1] == "-":
                    kraken_tmp[s][tmp_k[target_level]] = v

    kraken_data = kraken_tmp

# %%
# now to organize in a way that keeps a logical order intact
keylist = []

for k, e in kraken_data.items():
    for s, l in e.items():
        keylist.append(s) # just joining it up to make filtering duplicates out easier
        
keylist = [x.split('\t') for x in list(set(keylist))]
     
if not run_trimmed:
    for i in range(1, max_depth+1):
        keylist = sorted(keylist, key=lambda x: x[-i]) # need to sort it starting from the right col to keep it from re-sorting everything

# %%
with open('kraken2.csv', 'w') as f:
    kraken_keys = list(kraken_data.keys())
    f.write(",".join(['' for i in range(0, max_depth)]+kraken_keys)+"\n")

    for kl in keylist: # work through all of sorted rows 
        tmp_row = list(kl)
        tmp_key = '\t'.join(kl)
        
        for s in kraken_keys:
            if tmp_key in kraken_data[s]:
                tmp_row.append(kraken_data[s][tmp_key])
            else:
                tmp_row.append('NaN')
    
        f.write(",".join([str(s) for s in tmp_row])+"\n")

# %%
kraken_data
# Out:
# {'104': {'Bacteroidetes': '12616412',
#   'Chlorobi': '14',
#   'Rhodothermaeota': '1',
#   'Fibrobacteria': '13',
#   'Chitinivibrionia': '1',
#   'Clostridia': '4936810',
#   'Negativicutes': '584703',
#   'Bacilli': '230791',
#   'Erysipelotrichia': '24270',
#   'unclassified Firmicutes sensu stricto': '14677',
#   'Tissierellia': '6291',
#   'Limnochordia': '12',
#   'Actinobacteria': '262671',
#   'Coriobacteriia': '69758',
#   'Nitriliruptoria': '5',
#   'Rubrobacteria': '3',
#   'Acidimicrobiia': '2',
#   'Thermoleophilia': '1',
#   'Candidatus Melainabacteria': '82',
#   'Cyanobacteria': '54',
#   'Mollicutes': '76',
#   'unclassified Tenericutes': '1',
#   'Anaerolineae': '27',
#   'Chloroflexia': '4',
#   'Dehalococcoidia': '2',
#   'Deinococci': '29',
#   'Thermobaculum': '1',
#   'Burkholderiales': '275042',
#   'Rhodocyclales': '1648',
#   'Neisseriales': '79',
#   'Nitrosomonadales': '12',
#   'unclassified Betaproteobacteria': '3',
#   'Ferrovales': '2',
#   'Pseudomonadales': '12151',
#   'Enterobacterales': '1635',
#   'Oceanospirillales': '245',
#   'Alteromonadales': '145',
#   'Xanthomonadales': '57',
#   'Vibrionales': '45',
#   'Pasteurellales': '39',
#   'Aeromonadales': '17',
#   'Chromatiales': '14',
#   'Methylococcales': '8',
#   'Legionellales': '7',
#   'unclassified Gammaproteobacteria': '4',
#   'Nevskiales': '4',
#   'Cardiobacteriales': '3',
#   'Cellvibrionales': '2',
#   'Deltaproteobacteria': '5357',
#   'Epsilonproteobacteria': '445',
#   'Rhizobiales': '431',
#   'Rhodobacterales': '188',
#   'Sphingomonadales': '94',
#   'Rhodospirillales': '80',
#   'Caulobacterales': '12',
#   'Rickettsiales': '5',
#   'Pelagibacterales': '3',
#   'unclassified Alphaproteobacteria': '3',
#   'Parvularculales': '2',
#   'Acidithiobacillales': '7',
#   'Hydrogenophilales': '7',
#   'Silvanigrellales': '3',
#   'bacterium LF-3': '66',
#   'bacterium 1xD42-67': '33',
#   'bacterium D16-29': '24',
#   'bacterium 1XD8-76': '16',
#   'bacterium D16-50': '8',
#   'bacterium 1XD21-13': '5',
#   'bacterium 1XD42-8': '5',
#   'bacterium 1xD42-87': '4',
#   'bacterium D16-76': '4',
#   'bacterium 1XD8-92': '4',
#   'bacterium c-19': '3',
#   'bacterium 1xD42-62': '3',
#   'bacterium 1XD42-54': '2',
#   'bacterium 0.1xD8-82': '1',
#   'bacterium 0.1xD8-71': '1',
#   'bacterium D16-63': '1',
#   'Candidatus Saccharibacteria': '247',
#   'Verrucomicrobiae': '257',
#   'Opitutae': '7',
#   'unclassified Verrucomicrobia': '6',
#   'Lentisphaeria': '36',
#   'Planctomycetia': '6',
#   'unclassified Planctomycetes': '5',
#   'Chlamydiia': '5',
#   'Kiritimatiellae': '2',
#   'Fusobacteriales': '155',
#   'Spirochaetales': '26',
#   'Brachyspirales': '8',
#   'Leptospirales': '5',
#   'Synergistales': '33',
#   'Acidobacteriales': '7',
#   'unclassified Acidobacteria (miscellaneous)': '1',
#   'Petrotogales': '2',
#   'Thermotogales': '1',
#   'Kosmotogales': '1',
#   'Mesoaciditogales': '1',
#   'Methanobacteria': '251',
#   'Halobacteria': '52',
#   'Methanomicrobia': '4',
#   'Thermoplasmata': '4',
#   'Thermococcales': '2',
#   'Dikarya': '112',
#   'Fungi incertae sedis': '2'},
#  '104_dm': {'Bacteroidetes': 11179626,
#   'Clostridia': 3814260,
#   'Negativicutes': 508221,
#   'Burkholderiales': 221354,
#   'Actinobacteria': 176882,
#   'Bacilli': 148026,
#   'Erysipelotrichia': 82635,
#   'Coriobacteriia': 89292,
#   'Deltaproteobacteria': 28572,
#   'Oceanospirillales': 4973,
#   'Fusobacteriales': 3082,
#   'Spirochaetales': 2257,
#   'Pseudomonadales': 1503,
#   'Tissierellia': 2390,
#   'Enterobacterales': 2311,
#   'Rhodospirillales': 655,
#   'Brachyspirales': 342,
#   'Synergistales': 259,
#   'Epsilonproteobacteria': 329,
#   'Verrucomicrobiae': 211,
#   'Aeromonadales': 165,
#   'Rhizobiales': 58,
#   'Neisseriales': 10},
#  '1': {'Clostridia': '11889106',
#   'Negativicutes': '318999',
#   'unclassified Firmicutes sensu stricto': '155417',
#   'Bacilli': '62832',
#   'Erysipelotrichia': '49257',
#   'Tissierellia': '1198',
#   'Limnochordia': '7',
#   'Actinobacteria': '779033',
#   'Coriobacteriia': '586853',
#   'Thermoleophilia': '16',
#   'Rubrobacteria': '7',
#   'Acidimicrobiia': '6',
#   'Nitriliruptoria': '4',
#   'unclassified Actinobacteria': '1',
#   'Mollicutes': '1915',
#   'Candidatus Izimaplasma': '92',
#   'unclassified Tenericutes': '12',
#   'Candidatus Melainabacteria': '282',
#   'Cyanobacteria': '226',
#   'Deinococci': '176',
#   'Anaerolineae': '59',
#   'Dehalococcoidia': '59',
#   'Chloroflexia': '11',
#   'Ktedonobacteria': '7',
#   'Caldilineae': '4',
#   'Thermomicrobia': '2',
#   'Ardenticatenia': '2',
#   'Armatimonadia': '4',
#   'Fimbriimonadia': '3',
#   'Chthonomonadetes': '1',
#   'Bacteroidetes': '5731133',
#   'Chlorobi': '29',
#   'Ignavibacteriae': '2',
#   'Balneolaeota': '1',
#   'Fibrobacteria': '39',
#   'Chitinivibrionia': '1',
#   'Candidatus Marinimicrobia bacterium': '16',
#   'Gemmatimonadetes': '4',
#   'Candidatus Thermokryptus': '1',
#   'Candidatus Kryptobacter': '1',
#   'Verrucomicrobiae': '263468',
#   'unclassified Verrucomicrobia': '25',
#   'Opitutae': '21',
#   'Lentisphaeria': '23612',
#   'Planctomycetia': '52',
#   'unclassified Planctomycetes': '34',
#   'Candidatus Brocadiae': '3',
#   'Chlamydiia': '86',
#   'Kiritimatiellae': '5',
#   'unclassified Kiritimatiellaeota': '4',
#   'Burkholderiales': '81311',
#   'Rhodocyclales': '253',
#   'Neisseriales': '68',
#   'Nitrosomonadales': '54',
#   'unclassified Betaproteobacteria': '10',
#   'Deltaproteobacteria': '50597',
#   'Epsilonproteobacteria': '385',
#   'Enterobacterales': '18746',
#   'Pseudomonadales': '14773',
#   'Pasteurellales': '4588',
#   'Alteromonadales': '790',
#   'Xanthomonadales': '247',
#   'Oceanospirillales': '174',
#   'Vibrionales': '102',
#   'Chromatiales': '60',
#   'Aeromonadales': '49',
#   'unclassified Gammaproteobacteria': '31',
#   'Cellvibrionales': '30',
#   'Methylococcales': '25',
#   'Thiotrichales': '25',
#   'Legionellales': '24',
#   'Nevskiales': '17',
#   'Cardiobacteriales': '10',
#   'Orbales': '8',
#   'Salinisphaerales': '5',
#   'Acidiferrobacterales': '3',
#   'Rhizobiales': '1817',
#   'Rhodobacterales': '787',
#   'Sphingomonadales': '428',
#   'Rhodospirillales': '271',
#   'Caulobacterales': '34',
#   'Rickettsiales': '27',
#   'Pelagibacterales': '18',
#   'unclassified Alphaproteobacteria': '4',
#   'Sneathiellales': '2',
#   'Kiloniellales': '2',
#   'Micropepsales': '2',
#   'Holosporales': '2',
#   'Silvanigrellales': '8',
#   'Bdellovibrionales': '2',
#   'Hydrogenophilales': '3',
#   'Acidithiobacillales': '2',
#   'unclassified Proteobacteria (miscellaneous)': '1',
#   'bacterium LF-3': '2282',
#   'bacterium 1xD42-87': '193',
#   'bacterium D16-29': '189',
#   'bacterium 1xD42-62': '164',
#   'bacterium D16-50': '81',
#   'bacterium 1xD42-67': '77',
#   'bacterium 1XD8-76': '26',
#   'bacterium 1XD42-54': '26',
#   'bacterium 1XD21-13': '25',
#   'bacterium 1XD42-8': '16',
#   'bacterium D16-76': '15',
#   'bacterium c-19': '15',
#   'bacterium 1XD8-92': '9',
#   'bacterium D16-63': '8',
#   'bacterium 0.1xD8-71': '7',
#   'bacterium 0.1xD8-82': '6',
#   'bacterium 1xD42-11': '3',
#   'Bathymodiolus brooksi thiotrophic gill symbiont': '3',
#   'bacterium endosymbiont of Bathymodiolus sp. 5 South': '1',
#   'bacterium BCRC 81129': '1',
#   'bacterium D16-36': '1',
#   'Candidatus Saccharibacteria': '57',
#   'Patescibacteria group': '1',
#   'Haloplasmataceae': '12',
#   'unclassified Vampirococcus': '2',
#   'Fusobacteriales': '513',
#   'Synergistales': '411',
#   'Spirochaetales': '200',
#   'Brachyspirales': '89',
#   'Leptospirales': '20',
#   'Brevinematales': '2',
#   'Acidobacteriales': '27',
#   'Bryobacterales': '16',
#   'Holophagales': '4',
#   'Blastocatellales': '2',
#   'Vicinamibacteraceae': '2',
#   'Thermoanaerobaculales': '1',
#   'Thermotogales': '12',
#   'Petrotogales': '9',
#   'Mesoaciditogales': '4',
#   'Kosmotogales': '2',
#   'Deferribacterales': '11',
#   'Thermodesulfobacteriales': '4',
#   'Aquificales': '3',
#   'Desulfurobacteriales': '1',
#   'Nitrospirales': '4',
#   'Candidatus Entotheonella': '2',
#   'Nitrospinia': '1',
#   'Dictyoglomales': '2',
#   'Candidatus Cryosericia': '1',
#   'Calditrichales': '1',
#   'Dikarya': '789',
#   'Fungi incertae sedis': '19',
#   'Methanobacteria': '209',
#   'Methanococci': '4',
#   'Halobacteria': '165',
#   'Methanomicrobia': '17',
#   'Thermoplasmata': '4',
#   'Thermococcales': '3',
#   'Archaeoglobales': '1',
#   'Methanopyrales': '1',
#   'Thermoprotei': '5',
#   'Nitrosopumilales': '2',
#   'unclassified Thaumarchaeota': '2',
#   'Candidatus Prometheoarchaeum': '1'},
#  '1_dm': {'Bacteroidetes': 5209689,
#   'Clostridia': 10065081,
#   'Actinobacteria': 527564,
#   'Erysipelotrichia': 217513,
#   'Coriobacteriia': 315301,
#   'Negativicutes': 217112,
#   'Deltaproteobacteria': 122632,
#   'Burkholderiales': 63495,
#   'Bacilli': 63523,
#   'Verrucomicrobiae': 18272,
#   'Fusobacteriales': 11496,
#   'Enterobacterales': 13646,
#   'Oceanospirillales': 5900,
#   'Pseudomonadales': 4687,
#   'Synergistales': 1771,
#   'Rhodospirillales': 1145,
#   'Tissierellia': 1852,
#   'Spirochaetales': 667,
#   'Brachyspirales': 564,
#   'Epsilonproteobacteria': 813,
#   'Aeromonadales': 732,
#   'Rhizobiales': 243,
#   'Neisseriales': 56},
#  '16': {'Bacteroidetes': '14900324',
#   'Chlorobi': '23',
#   'Ignavibacteriae': '3',
#   'Rhodothermaeota': '2',
#   'Balneolaeota': '2',
#   'unclassified Bacteroidetes/Chlorobi group': '1',
#   'Fibrobacteria': '59',
#   'Candidatus Marinimicrobia bacterium': '5',
#   'Gemmatimonadetes': '2',
#   'Clostridia': '6140954',
#   'Negativicutes': '183558',
#   'Bacilli': '28739',
#   'Erysipelotrichia': '26363',
#   'unclassified Firmicutes sensu stricto': '25819',
#   'Tissierellia': '740',
#   'Limnochordia': '5',
#   'Coriobacteriia': '250579',
#   'Actinobacteria': '27181',
#   'Acidimicrobiia': '8',
#   'Thermoleophilia': '6',
#   'Rubrobacteria': '3',
#   'Nitriliruptoria': '3',
#   'Cyanobacteria': '310',
#   'Candidatus Melainabacteria': '187',
#   'Mollicutes': '159',
#   'unclassified Tenericutes': '1',
#   'Deinococci': '107',
#   'Anaerolineae': '14',
#   'Chloroflexia': '4',
#   'Dehalococcoidia': '3',
#   'Ktedonobacteria': '3',
#   'Ardenticatenia': '3',
#   'Candidatus Thermofonsia': '2',
#   'Armatimonadia': '1',
#   'Deltaproteobacteria': '152019',
#   'Epsilonproteobacteria': '433',
#   'Burkholderiales': '84693',
#   'Rhodocyclales': '2385',
#   'Neisseriales': '395',
#   'Nitrosomonadales': '31',
#   'unclassified Betaproteobacteria': '4',
#   'Pseudomonadales': '22374',
#   'Enterobacterales': '9689',
#   'Alteromonadales': '838',
#   'Cardiobacteriales': '262',
#   'Xanthomonadales': '142',
#   'Oceanospirillales': '132',
#   'Pasteurellales': '126',
#   'Vibrionales': '85',
#   'Methylococcales': '74',
#   'Chromatiales': '59',
#   'Legionellales': '46',
#   'Aeromonadales': '41',
#   'Cellvibrionales': '36',
#   'unclassified Gammaproteobacteria': '17',
#   'Thiotrichales': '14',
#   'Salinisphaerales': '12',
#   'Acidiferrobacterales': '5',
#   'Nevskiales': '5',
#   'Orbales': '2',
#   'Rhizobiales': '1772',
#   'Rhodobacterales': '1177',
#   'Rhodospirillales': '640',
#   'Sphingomonadales': '361',
#   'Rickettsiales': '49',
#   'Caulobacterales': '26',
#   'Kiloniellales': '23',
#   'unclassified Alphaproteobacteria': '22',
#   'Sneathiellales': '19',
#   'Pelagibacterales': '16',
#   'Kordiimonadales': '7',
#   'Magnetococcales': '3',
#   'Parvularculales': '1',
#   'Rhodothalassiales': '1',
#   'Micropepsales': '1',
#   'Emcibacterales': '1',
#   'Bdellovibrionales': '8',
#   'Bacteriovoracales': '2',
#   'Mariprofundales': '4',
#   'Acidithiobacillales': '2',
#   'Hydrogenophilales': '1',
#   'Verrucomicrobiae': '84587',
#   'unclassified Verrucomicrobia': '10',
#   'Opitutae': '9',
#   'Spartobacteria': '1',
#   'Lentisphaeria': '37071',
#   'Planctomycetia': '52',
#   'unclassified Planctomycetes': '19',
#   'Phycisphaerae': '3',
#   'Candidatus Brocadiae': '3',
#   'unclassified Kiritimatiellaeota': '11',
#   'Chlamydiia': '3',
#   'Synergistales': '2907',
#   'bacterium LF-3': '166',
#   'bacterium 1xD42-67': '126',
#   'bacterium D16-29': '122',
#   'bacterium D16-50': '51',
#   'bacterium D16-76': '27',
#   'bacterium 1XD8-92': '16',
#   'bacterium 1XD42-54': '16',
#   'bacterium 1xD42-87': '14',
#   'bacterium 0.1xD8-82': '13',
#   'bacterium 1XD21-13': '13',
#   'bacterium c-19': '11',
#   'bacterium 1xD42-62': '8',
#   'bacterium 1XD8-76': '7',
#   'bacterium 0.1xD8-71': '7',
#   'bacterium 1XD42-1': '6',
#   'bacterium YEK0313': '2',
#   'bacterium D16-63': '2',
#   'bacterium SGD-2': '2',
#   'bacterium 1XD42-8': '1',
#   'bacterium JGI 053': '1',
#   'bacterium BCRC 81127': '1',
#   'bacterium 2013Arg42i': '1',
#   'Candidatus Saccharibacteria': '246',
#   'Candidatus Atribacteria': '2',
#   'Isachenkonia alkalipeptolytica': '2',
#   'unclassified Vampirococcus': '1',
#   'Fusobacteriales': '121',
#   'Spirochaetales': '75',
#   'Brachyspirales': '21',
#   'Leptospirales': '14',
#   'Acidobacteriales': '20',
#   'Bryobacterales': '1',
#   'Holophagales': '1',
#   'Candidatus Entotheonella': '10',
#   'Nitrospinia': '1',
#   'Aquificales': '8',
#   'Desulfurobacteriales': '2',
#   'Thermotogales': '4',
#   'Petrotogales': '4',
#   'Kosmotogales': '1',
#   'Nitrospirales': '4',
#   'Nitrospirae bacterium HCH-1': '1',
#   'Elusimicrobiales': '3',
#   'Candidatus Cryosericia': '2',
#   'Thermodesulfobacteriales': '2',
#   'Deferribacterales': '1',
#   'Dikarya': '806',
#   'Fungi incertae sedis': '15',
#   'Methanobacteria': '139',
#   'Methanococci': '4',
#   'Halobacteria': '51',
#   'Methanomicrobia': '26',
#   'Thermococcales': '7',
#   'Thermoplasmata': '6',
#   'DHVE2 group': '1',
#   'Methanopyrales': '2',
#   'Archaeoglobales': '1',
#   'Thermoprotei': '3'},
#  '97': {'Clostridia': '10349746',
#   'Erysipelotrichia': '612479',
#   'unclassified Firmicutes sensu stricto': '569163',
#   'Negativicutes': '511689',
#   'Bacilli': '200553',
#   'Tissierellia': '1115',
#   'Limnochordia': '6',
#   'Coriobacteriia': '264253',
#   'Actinobacteria': '120526',
#   'Thermoleophilia': '9',
#   'Nitriliruptoria': '8',
#   'Rubrobacteria': '7',
#   'Acidimicrobiia': '2',
#   'unclassified Actinobacteria': '1',
#   'Candidatus Melainabacteria': '94735',
#   'Cyanobacteria': '195',
#   'Mollicutes': '929',
#   'unclassified Tenericutes': '20',
#   'Candidatus Izimaplasma': '16',
#   'Anaerolineae': '47',
#   'Caldilineae': '46',
#   'Chloroflexia': '24',
#   'Dehalococcoidia': '9',
#   'Ktedonobacteria': '5',
#   'Ardenticatenia': '5',
#   'Thermoflexia': '3',
#   'Candidatus Thermofonsia': '1',
#   'Deinococci': '101',
#   'Armatimonadia': '1',
#   'Chthonomonadetes': '1',
#   'Fimbriimonadia': '1',
#   'Thermobaculum': '2',
#   'Bacteroidetes': '6872347',
#   'Chlorobi': '24',
#   'Ignavibacteriae': '5',
#   'Rhodothermaeota': '4',
#   'Balneolaeota': '3',
#   'Fibrobacteria': '70',
#   'Gemmatimonadetes': '4',
#   'Candidatus Marinimicrobia bacterium': '3',
#   'Candidatus Kryptobacter': '1',
#   'Burkholderiales': '281654',
#   'Rhodocyclales': '294',
#   'Neisseriales': '155',
#   'Nitrosomonadales': '68',
#   'unclassified Betaproteobacteria': '9',
#   'Deltaproteobacteria': '121929',
#   'Epsilonproteobacteria': '667',
#   'Pseudomonadales': '59069',
#   'Enterobacterales': '46303',
#   'Oceanospirillales': '261',
#   'Alteromonadales': '257',
#   'Xanthomonadales': '220',
#   'Pasteurellales': '202',
#   'Vibrionales': '170',
#   'Chromatiales': '64',
#   'Aeromonadales': '59',
#   'Cellvibrionales': '55',
#   'Methylococcales': '23',
#   'Orbales': '15',
#   'Legionellales': '13',
#   'unclassified Gammaproteobacteria': '12',
#   'Nevskiales': '11',
#   'Thiotrichales': '10',
#   'Cardiobacteriales': '8',
#   'Acidiferrobacterales': '2',
#   'Salinisphaerales': '1',
#   'Rhizobiales': '1326',
#   'Rhodobacterales': '646',
#   'Sphingomonadales': '241',
#   'Rhodospirillales': '234',
#   'Caulobacterales': '45',
#   'Rickettsiales': '24',
#   'Pelagibacterales': '19',
#   'unclassified Alphaproteobacteria': '12',
#   'Parvularculales': '4',
#   'Minwuiales': '1',
#   'Holosporales': '1',
#   'Magnetococcales': '1',
#   'Sneathiellales': '1',
#   'Silvanigrellales': '7',
#   'Bdellovibrionales': '3',
#   'Bacteriovoracales': '3',
#   'Hydrogenophilales': '8',
#   'Acidithiobacillales': '6',
#   'Mariprofundales': '1',
#   'Lentisphaeria': '40065',
#   'Verrucomicrobiae': '30137',
#   'Opitutae': '28',
#   'unclassified Verrucomicrobia': '7',
#   'Spartobacteria': '3',
#   'Planctomycetia': '27',
#   'unclassified Planctomycetes': '25',
#   'Phycisphaerae': '3',
#   'Candidatus Brocadiae': '1',
#   'Kiritimatiellae': '8',
#   'unclassified Kiritimatiellaeota': '3',
#   'Chlamydiia': '10',
#   'bacterium 1xD42-67': '133',
#   'bacterium D16-29': '133',
#   'bacterium D16-76': '131',
#   'bacterium 1XD42-54': '52',
#   'bacterium D16-50': '50',
#   'bacterium LF-3': '43',
#   'bacterium 0.1xD8-82': '24',
#   'bacterium 1XD21-13': '22',
#   'bacterium 0.1xD8-71': '17',
#   'bacterium 1xD42-62': '17',
#   'bacterium 1XD8-76': '14',
#   'bacterium c-19': '14',
#   'bacterium 1XD42-8': '11',
#   'bacterium JKG1': '10',
#   'bacterium 1xD42-87': '9',
#   'bacterium D16-63': '4',
#   'bacterium 1XD8-92': '3',
#   'bacterium SGD-2': '1',
#   'Candidatus Saccharibacteria': '586',
#   'Candidatus Dependentiae': '1',
#   'candidate division NC10': '1',
#   'Haloplasmataceae': '9',
#   'Fusobacteriales': '471',
#   'Spirochaetales': '179',
#   'Brachyspirales': '98',
#   'Leptospirales': '21',
#   'Synergistales': '287',
#   'Acidobacteriales': '29',
#   'Bryobacterales': '6',
#   'Holophagales': '6',
#   'unclassified Acidobacteria (miscellaneous)': '1',
#   'Blastocatellales': '1',
#   'Thermoanaerobaculales': '1',
#   'Petrotogales': '15',
#   'Thermotogales': '12',
#   'Kosmotogales': '8',
#   'Endomicrobiales': '1',
#   'Elusimicrobiales': '1',
#   'Aquificales': '8',
#   'Desulfurobacteriales': '1',
#   'Nitrospirales': '9',
#   'Deferribacterales': '5',
#   'Thermodesulfobacteriales': '3',
#   'Nitrospinia': '1',
#   'Candidatus Entotheonella': '1',
#   'Candidatus Cryosericia': '2',
#   'Chrysiogenales': '1',
#   'Coprothermobacterales': '1',
#   'Methanobacteria': '122095',
#   'Methanococci': '7',
#   'Thermoplasmata': '3350',
#   'Halobacteria': '93',
#   'Methanomicrobia': '38',
#   'Thermococcales': '10',
#   'Methanopyrales': '4',
#   'Methanonatronarchaeales': '1',
#   'Nitrosopumilales': '2',
#   'Nitrososphaeria': '1',
#   'Thermoprotei': '3',
#   'Dikarya': '2215',
#   'Fungi incertae sedis': '29'},
#  '97_dm': {'Bacteroidetes': 6928767,
#   'Clostridia': 8531791,
#   'Erysipelotrichia': 841752,
#   'Negativicutes': 335344,
#   'Burkholderiales': 247289,
#   'Coriobacteriia': 212159,
#   'Deltaproteobacteria': 145402,
#   'Actinobacteria': 79897,
#   'Bacilli': 110772,
#   'Fusobacteriales': 14449,
#   'Enterobacterales': 16176,
#   'Oceanospirillales': 6672,
#   'Pseudomonadales': 4156,
#   'Verrucomicrobiae': 2594,
#   'Synergistales': 1487,
#   'Spirochaetales': 1281,
#   'Tissierellia': 2067,
#   'Epsilonproteobacteria': 1161,
#   'Rhodospirillales': 763,
#   'Brachyspirales': 572,
#   'Aeromonadales': 468,
#   'Rhizobiales': 228,
#   'Neisseriales': 52},
#  '13': {'Clostridia': '11335430',
#   'Negativicutes': '413982',
#   'Erysipelotrichia': '300952',
#   'unclassified Firmicutes sensu stricto': '167330',
#   'Bacilli': '44137',
#   'Tissierellia': '3524',
#   'Limnochordia': '5',
#   'Coriobacteriia': '352344',
#   'Actinobacteria': '113863',
#   'Thermoleophilia': '32',
#   'Rubrobacteria': '19',
#   'Acidimicrobiia': '6',
#   'Nitriliruptoria': '6',
#   'unclassified Actinobacteria': '1',
#   'Candidatus Melainabacteria': '1571',
#   'Cyanobacteria': '311',
#   'Candidatus Margulisbacteria': '2',
#   'Mollicutes': '1315',
#   'Candidatus Izimaplasma': '149',
#   'unclassified Tenericutes': '17',
#   'Anaerolineae': '217',
#   'Chloroflexia': '27',
#   'Ktedonobacteria': '18',
#   'Dehalococcoidia': '14',
#   'Caldilineae': '14',
#   'Thermomicrobia': '8',
#   'Ardenticatenia': '8',
#   'Thermoflexia': '4',
#   'Tepidiformia': '4',
#   'Candidatus Thermofonsia': '1',
#   'Deinococci': '222',
#   'Armatimonadia': '15',
#   'Chthonomonadetes': '10',
#   'unclassified Armatimonadetes': '2',
#   'Fimbriimonadia': '2',
#   'Thermobaculum': '3',
#   'Bacteroidetes': '5677982',
#   'Chlorobi': '58',
#   'Balneolaeota': '15',
#   'Rhodothermaeota': '12',
#   'unclassified Bacteroidetes/Chlorobi group': '3',
#   'Fibrobacteria': '303',
#   'Gemmatimonadetes': '8',
#   'Candidatus Marinimicrobia bacterium': '4',
#   'candidate division Zixibacteria bacterium': '2',
#   'Candidatus Cloacimonas': '1',
#   'Candidatus Thermokryptus': '1',
#   'Enterobacterales': '1026983',
#   'Pseudomonadales': '4656',
#   'Alteromonadales': '1751',
#   'Xanthomonadales': '566',
#   'Oceanospirillales': '268',
#   'Chromatiales': '252',
#   'Vibrionales': '193',
#   'Pasteurellales': '178',
#   'Aeromonadales': '118',
#   'Legionellales': '97',
#   'Methylococcales': '75',
#   'Cellvibrionales': '63',
#   'unclassified Gammaproteobacteria': '44',
#   'Thiotrichales': '33',
#   'Nevskiales': '30',
#   'Orbales': '17',
#   'Salinisphaerales': '14',
#   'Cardiobacteriales': '7',
#   'Acidiferrobacterales': '3',
#   'Deltaproteobacteria': '168121',
#   'Epsilonproteobacteria': '1648',
#   'Burkholderiales': '42853',
#   'Rhodocyclales': '5300',
#   'Neisseriales': '173',
#   'Nitrosomonadales': '80',
#   'unclassified Betaproteobacteria': '22',
#   'Rhizobiales': '3085',
#   'Rhodobacterales': '1512',
#   'Rhodospirillales': '783',
#   'Sphingomonadales': '683',
#   'Caulobacterales': '110',
#   'Rickettsiales': '90',
#   'Pelagibacterales': '89',
#   'unclassified Alphaproteobacteria': '17',
#   'Kiloniellales': '9',
#   'Sneathiellales': '6',
#   'Holosporales': '5',
#   'Parvularculales': '4',
#   'Minwuiales': '3',
#   'Emcibacterales': '3',
#   'Micropepsales': '3',
#   'Magnetococcales': '2',
#   'Rhodothalassiales': '1',
#   'Kordiimonadales': '1',
#   'Acidithiobacillales': '27',
#   'Silvanigrellales': '15',
#   'Bacteriovoracales': '5',
#   'Bdellovibrionales': '3',
#   'Hydrogenophilales': '10',
#   'Mariprofundales': '3',
#   'unclassified Proteobacteria (miscellaneous)': '1',
#   'Verrucomicrobiae': '226863',
#   'Opitutae': '129',
#   'unclassified Verrucomicrobia': '11',
#   'Spartobacteria': '5',
#   'Methylacidiphilae': '3',
#   'Lentisphaeria': '14293',
#   'Planctomycetia': '94',
#   'unclassified Planctomycetes': '61',
#   'Phycisphaerae': '12',
#   'Candidatus Brocadiae': '9',
#   'Kiritimatiellae': '10',
#   'unclassified Kiritimatiellaeota': '6',
#   'Chlamydiia': '16',
#   'Synergistales': '7564',
#   'bacterium LF-3': '3373',
#   'bacterium 1xD42-67': '324',
#   'bacterium D16-29': '198',
#   'bacterium 1XD21-13': '96',
#   'bacterium D16-50': '79',
#   'bacterium c-19': '75',
#   'bacterium 1xD42-62': '34',
#   'bacterium 1xD42-87': '32',
#   'bacterium 1XD8-76': '29',
#   'bacterium 0.1xD8-82': '29',
#   'bacterium 1XD42-54': '25',
#   'bacterium 1xD42-11': '23',
#   'bacterium D16-76': '21',
#   'bacterium 0.1xD8-71': '18',
#   'bacterium 1XD42-8': '13',
#   'bacterium D16-63': '8',
#   'bacterium endosymbiont of Pedicinus badii': '6',
#   'bacterium 1XD8-92': '4',
#   'bacterium A52C2': '3',
#   'bacterium 1XD42-1': '1',
#   'Candidatus Saccharibacteria': '691',
#   'Patescibacteria group': '27',
#   'Candidatus Dependentiae': '1',
#   'Isachenkonia alkalipeptolytica': '4',
#   'Haloplasmataceae': '3',
#   'Natronospirillum operossus': '3',
#   'Fusobacteriales': '638',
#   'Spirochaetales': '263',
#   'Brachyspirales': '99',
#   'Leptospirales': '36',
#   'Brevinematales': '1',
#   'Acidobacteriales': '71',
#   'Bryobacterales': '25',
#   'Holophagales': '20',
#   'Chloracidobacterium': '2',
#   'Blastocatellales': '1',
#   'unclassified Acidobacteria (miscellaneous)': '2',
#   'Thermoanaerobaculales': '1',
#   'Petrotogales': '32',
#   'Thermotogales': '13',
#   'Mesoaciditogales': '7',
#   'Kosmotogales': '6',
#   'Aquificales': '17',
#   'Desulfurobacteriales': '8',
#   'Dictyoglomales': '18',
#   'Nitrospirales': '11',
#   'Nitrospirae bacterium HCH-1': '2',
#   'Elusimicrobiales': '2',
#   'Endomicrobiales': '1',
#   'Nitrospinia': '6',
#   'Candidatus Entotheonella': '2',
#   'Deferribacterales': '6',
#   'Chrysiogenales': '5',
#   'Thermodesulfobacteriales': '5',
#   'Candidatus Cryosericia': '3',
#   'Methanobacteria': '158453',
#   'Methanococci': '8',
#   'Halobacteria': '187',
#   'Methanomicrobia': '42',
#   'Thermococcales': '12',
#   'Thermoplasmata': '7',
#   'Archaeoglobales': '1',
#   'Thermoprotei': '19',
#   'Nitrosopumilales': '4',
#   'Nitrososphaeria': '1',
#   'Candidatus Methanodesulfokores': '1',
#   'Candidatus Prometheoarchaeum': '2',
#   'Dikarya': '881',
#   'Fungi incertae sedis': '31'},
#  '15': {'Clostridia': '6877372',
#   'Erysipelotrichia': '210613',
#   'Bacilli': '163172',
#   'unclassified Firmicutes sensu stricto': '156244',
#   'Negativicutes': '53005',
#   'Tissierellia': '620',
#   'Limnochordia': '5',
#   'Coriobacteriia': '344986',
#   'Actinobacteria': '213458',
#   'Thermoleophilia': '11',
#   'Rubrobacteria': '6',
#   'Nitriliruptoria': '4',
#   'Acidimicrobiia': '2',
#   'Candidatus Melainabacteria': '11713',
#   'Cyanobacteria': '801',
#   'Mollicutes': '254',
#   'unclassified Tenericutes': '1',
#   'Deinococci': '116',
#   'Anaerolineae': '56',
#   'Dehalococcoidia': '11',
#   'Chloroflexia': '9',
#   'Ktedonobacteria': '5',
#   'Caldilineae': '5',
#   'Thermomicrobia': '4',
#   'Candidatus Thermofonsia': '2',
#   'Ardenticatenia': '1',
#   'Thermoflexia': '1',
#   'unclassified Armatimonadetes': '2',
#   'Armatimonadia': '1',
#   'Chthonomonadetes': '1',
#   'Bacteroidetes': '5557269',
#   'Chlorobi': '32',
#   'Balneolaeota': '3',
#   'unclassified Bacteroidetes/Chlorobi group': '2',
#   'Fibrobacteria': '146',
#   'Candidatus Cloacimonas': '1',
#   'Gemmatimonadetes': '1',
#   'Verrucomicrobiae': '600217',
#   'Opitutae': '77',
#   'Spartobacteria': '10',
#   'unclassified Verrucomicrobia': '3',
#   'Methylacidiphilae': '1',
#   'Lentisphaeria': '100404',
#   'unclassified Planctomycetes': '42',
#   'Planctomycetia': '41',
#   'Phycisphaerae': '5',
#   'Candidatus Brocadiae': '2',
#   'Kiritimatiellae': '13',
#   'unclassified Kiritimatiellaeota': '1',
#   'Chlamydiia': '8',
#   'Burkholderiales': '373540',
#   'Rhodocyclales': '216',
#   'Neisseriales': '159',
#   'Nitrosomonadales': '28',
#   'unclassified Betaproteobacteria': '8',
#   'Deltaproteobacteria': '113452',
#   'Epsilonproteobacteria': '901',
#   'Enterobacterales': '40903',
#   'Pseudomonadales': '17016',
#   'Pasteurellales': '6904',
#   'Alteromonadales': '246',
#   'Xanthomonadales': '232',
#   'Aeromonadales': '193',
#   'Vibrionales': '123',
#   'Oceanospirillales': '119',
#   'Chromatiales': '82',
#   'Cardiobacteriales': '37',
#   'Cellvibrionales': '37',
#   'unclassified Gammaproteobacteria': '24',
#   'Methylococcales': '19',
#   'Thiotrichales': '16',
#   'Legionellales': '10',
#   'Nevskiales': '9',
#   'Orbales': '2',
#   'Acidiferrobacterales': '2',
#   'Salinisphaerales': '1',
#   'Rhizobiales': '1901',
#   'Rhodobacterales': '601',
#   'Rhodospirillales': '388',
#   'Sphingomonadales': '349',
#   'Caulobacterales': '36',
#   'Pelagibacterales': '26',
#   'Rickettsiales': '12',
#   'unclassified Alphaproteobacteria': '5',
#   'Parvularculales': '3',
#   'Emcibacterales': '2',
#   'Magnetococcales': '1',
#   'Rhodothalassiales': '1',
#   'Holosporales': '1',
#   'Hydrogenophilales': '11',
#   'Bacteriovoracales': '3',
#   'Oligoflexales': '1',
#   'Silvanigrellales': '1',
#   'Mariprofundales': '1',
#   'Acidithiobacillales': '1',
#   'Candidatus Saccharibacteria': '1624',
#   'candidate division NC10': '2',
#   'bacterium LF-3': '221',
#   'bacterium 1xD42-67': '172',
#   'bacterium D16-29': '158',
#   'bacterium D16-50': '42',
#   'bacterium 0.1xD8-82': '32',
#   'bacterium 1XD21-13': '30',
#   'bacterium 1XD42-54': '25',
#   'bacterium 1xD42-62': '22',
#   'bacterium 1XD8-76': '15',
#   'bacterium 1xD42-87': '14',
#   'bacterium D16-76': '11',
#   'bacterium 0.1xD8-71': '6',
#   'bacterium BCRC 81127': '5',
#   'bacterium 1XD8-92': '4',
#   'bacterium 1XD42-8': '3',
#   'bacterium M00.F.Ca.ET.230.01.1.1': '1',
#   'bacterium c-19': '1',
#   'bacterium D16-63': '1',
#   'bacterium BCRC 81129': '1',
#   'Bathymodiolus heckerae thiotrophic gill symbiont': '1',
#   'Haloplasmataceae': '1',
#   'Spirochaetales': '151',
#   'Leptospirales': '36',
#   'Brachyspirales': '29',
#   'Brevinematales': '1',
#   'Synergistales': '210',
#   'Fusobacteriales': '206',
#   'Acidobacteriales': '24',
#   'Bryobacterales': '4',
#   'Holophagales': '8',
#   'Blastocatellales': '3',
#   'Thermoanaerobaculales': '1',
#   'Petrotogales': '7',
#   'Kosmotogales': '6',
#   'Thermotogales': '2',
#   'Nitrospirales': '6',
#   'Aquificales': '4',
#   'Desulfurobacteriales': '1',
#   'Nitrospinia': '2',
#   'Candidatus Entotheonella': '2',
#   'Candidatus Cryosericia': '3',
#   'Thermodesulfobacteriales': '3',
#   'Deferribacterales': '3',
#   'Calditrichales': '1',
#   'Coprothermobacterales': '1',
#   'Dikarya': '3425',
#   'Fungi incertae sedis': '79',
#   'Halobacteria': '88',
#   'Methanomicrobia': '15',
#   'Methanobacteria': '93',
#   'Methanococci': '3',
#   'Thermoplasmata': '6',
#   'Thermococcales': '4',
#   'Methanopyrales': '1',
#   'Nitrososphaeria': '5',
#   'Nitrosopumilales': '2',
#   'Thermoprotei': '4'},
#  '101': {'Clostridia': '9741096',
#   'Bacilli': '1440438',
#   'Negativicutes': '136912',
#   'unclassified Firmicutes sensu stricto': '75205',
#   'Erysipelotrichia': '59204',
#   'Tissierellia': '103',
#   'Limnochordia': '5',
#   'Actinobacteria': '467954',
#   'Coriobacteriia': '360260',
#   'Acidimicrobiia': '3',
#   'Rubrobacteria': '3',
#   'Thermoleophilia': '3',
#   'Nitriliruptoria': '1',
#   'unclassified Actinobacteria': '1',
#   'Candidatus Melainabacteria': '157',
#   'Cyanobacteria': '96',
#   'Mollicutes': '110',
#   'Anaerolineae': '10',
#   'Dehalococcoidia': '9',
#   'Ardenticatenia': '5',
#   'Ktedonobacteria': '3',
#   'Caldilineae': '3',
#   'Thermomicrobia': '2',
#   'Chloroflexia': '1',
#   'Deinococci': '21',
#   'Chthonomonadetes': '1',
#   'Bacteroidetes': '5003471',
#   'Chlorobi': '12',
#   'Rhodothermaeota': '4',
#   'Fibrobacteria': '26',
#   'Chitinivibrionia': '1',
#   'Gemmatimonadetes': '2',
#   'Candidatus Marinimicrobia bacterium': '1',
#   'Enterobacterales': '1469592',
#   'Pseudomonadales': '44156',
#   'Pasteurellales': '1984',
#   'Xanthomonadales': '442',
#   'Oceanospirillales': '305',
#   'Alteromonadales': '219',
#   'Aeromonadales': '210',
#   'Vibrionales': '179',
#   'Legionellales': '62',
#   'Thiotrichales': '42',
#   'Methylococcales': '36',
#   'Chromatiales': '28',
#   'unclassified Gammaproteobacteria': '17',
#   'Cellvibrionales': '15',
#   'Nevskiales': '15',
#   'Cardiobacteriales': '12',
#   'Orbales': '6',
#   'Acidiferrobacterales': '2',
#   'Salinisphaerales': '1',
#   'Burkholderiales': '33922',
#   'Neisseriales': '113',
#   'Rhodocyclales': '54',
#   'Nitrosomonadales': '34',
#   'unclassified Betaproteobacteria': '6',
#   'Sphingomonadales': '14500',
#   'Rhizobiales': '7394',
#   'Caulobacterales': '3781',
#   'Rhodospirillales': '1267',
#   'Rhodobacterales': '250',
#   'unclassified Alphaproteobacteria': '16',
#   'Rickettsiales': '11',
#   'Pelagibacterales': '2',
#   'Sneathiellales': '2',
#   'Minwuiales': '1',
#   'Emcibacterales': '1',
#   'Magnetococcales': '1',
#   'Kordiimonadales': '1',
#   'Parvularculales': '1',
#   'Deltaproteobacteria': '13466',
#   'Epsilonproteobacteria': '694',
#   'Hydrogenophilales': '3',
#   'Bdellovibrionales': '1',
#   'Bacteriovoracales': '1',
#   'Acidithiobacillales': '2',
#   'unclassified Proteobacteria (miscellaneous)': '1',
#   'bacterium 1XD42-8': '203',
#   'bacterium M00.F.Ca.ET.230.01.1.1': '170',
#   'bacterium LF-3': '84',
#   'bacterium 0.1xD8-82': '38',
#   'bacterium D16-50': '17',
#   'bacterium 1XD42-54': '17',
#   'bacterium D16-29': '17',
#   'bacterium 1xD42-67': '15',
#   'bacterium 1xD42-87': '11',
#   'bacterium 1XD8-76': '10',
#   'bacterium 1XD21-13': '7',
#   'bacterium 1xD42-62': '6',
#   'bacterium D16-76': '4',
#   'bacterium 0.1xD8-71': '2',
#   'bacterium 1XD8-92': '2',
#   'bacterium JKG1': '1',
#   'Candidatus Saccharibacteria': '234',
#   'Verrucomicrobiae': '747',
#   'Opitutae': '9',
#   'unclassified Verrucomicrobia': '2',
#   'Lentisphaeria': '63',
#   'Planctomycetia': '31',
#   'unclassified Planctomycetes': '25',
#   'Phycisphaerae': '1',
#   'Chlamydiia': '15',
#   'unclassified Kiritimatiellaeota': '1',
#   'Fusobacteriales': '435',
#   'Synergistales': '83',
#   'Spirochaetales': '48',
#   'Leptospirales': '6',
#   'Brachyspirales': '4',
#   'Acidobacteriales': '18',
#   'Bryobacterales': '9',
#   'Holophagales': '1',
#   'Vicinamibacteraceae': '1',
#   'Petrotogales': '3',
#   'Thermotogales': '2',
#   'Deferribacterales': '5',
#   'Elusimicrobiales': '2',
#   'Dictyoglomales': '1',
#   'Coprothermobacterales': '1',
#   'Thermodesulfobacteriales': '1',
#   'Methanobacteria': '2777',
#   'Methanococci': '1',
#   'Halobacteria': '29',
#   'Thermococcales': '1',
#   'unclassified Thaumarchaeota': '2',
#   'Nitrosopumilales': '1',
#   'Thermoprotei': '1',
#   'Dikarya': '789',
#   'Fungi incertae sedis': '5'},
#  '3': {'Bacteroidetes': '11587742',
#   'Chlorobi': '34',
#   'Balneolaeota': '11',
#   'Ignavibacteriae': '3',
#   'unclassified Bacteroidetes/Chlorobi group': '1',
#   'Rhodothermaeota': '1',
#   'Fibrobacteria': '377',
#   'Chitinivibrionia': '1',
#   'Candidatus Marinimicrobia bacterium': '4',
#   'Gemmatimonadetes': '3',
#   'Candidatus Cloacimonas': '2',
#   'Candidatus Thermokryptus': '1',
#   'Clostridia': '4679740',
#   'Erysipelotrichia': '617640',
#   'Negativicutes': '595851',
#   'unclassified Firmicutes sensu stricto': '119322',
#   'Bacilli': '89119',
#   'Tissierellia': '381',
#   'Limnochordia': '3',
#   'Coriobacteriia': '235314',
#   'Actinobacteria': '65178',
#   'Thermoleophilia': '11',
#   'Nitriliruptoria': '8',
#   'Acidimicrobiia': '5',
#   'Rubrobacteria': '5',
#   'unclassified Actinobacteria': '1',
#   'Candidatus Melainabacteria': '128',
#   'Cyanobacteria': '114',
#   'Mollicutes': '142',
#   'Candidatus Izimaplasma': '2',
#   'unclassified Tenericutes': '1',
#   'Deinococci': '42',
#   'Anaerolineae': '13',
#   'Dehalococcoidia': '8',
#   'Ktedonobacteria': '8',
#   'Chloroflexia': '3',
#   'Ardenticatenia': '2',
#   'Thermomicrobia': '1',
#   'Caldilineae': '1',
#   'Tepidiformia': '1',
#   'Armatimonadia': '1',
#   'unclassified Armatimonadetes': '1',
#   'Chthonomonadetes': '1',
#   'Fimbriimonadia': '1',
#   'Burkholderiales': '65321',
#   'Rhodocyclales': '945',
#   'Neisseriales': '118',
#   'Nitrosomonadales': '27',
#   'unclassified Betaproteobacteria': '6',
#   'Pseudomonadales': '14787',
#   'Pasteurellales': '6205',
#   'Enterobacterales': '3839',
#   'Alteromonadales': '539',
#   'Xanthomonadales': '458',
#   'Vibrionales': '141',
#   'Oceanospirillales': '109',
#   'Chromatiales': '47',
#   'Aeromonadales': '39',
#   'Cardiobacteriales': '34',
#   'Cellvibrionales': '23',
#   'unclassified Gammaproteobacteria': '18',
#   'Methylococcales': '12',
#   'Nevskiales': '8',
#   'Thiotrichales': '7',
#   'Legionellales': '4',
#   'Orbales': '4',
#   'Salinisphaerales': '1',
#   'Deltaproteobacteria': '4731',
#   'Epsilonproteobacteria': '344',
#   'Rhizobiales': '899',
#   'Rhodobacterales': '352',
#   'Sphingomonadales': '193',
#   'Rhodospirillales': '116',
#   'Caulobacterales': '61',
#   'Rickettsiales': '10',
#   'Pelagibacterales': '8',
#   'unclassified Alphaproteobacteria': '3',
#   'Kordiimonadales': '1',
#   'Holosporales': '1',
#   'Magnetococcales': '1',
#   'Parvularculales': '1',
#   'Bacteriovoracales': '4',
#   'Silvanigrellales': '1',
#   'Mariprofundales': '2',
#   'Acidithiobacillales': '1',
#   'Lentisphaeria': '6384',
#   'Verrucomicrobiae': '420',
#   'Opitutae': '34',
#   'unclassified Verrucomicrobia': '4',
#   'Spartobacteria': '1',
#   'Planctomycetia': '31',
#   'unclassified Planctomycetes': '14',
#   'Phycisphaerae': '5',
#   'Chlamydiia': '7',
#   'Kiritimatiellae': '2',
#   'bacterium D16-29': '68',
#   'bacterium 1xD42-67': '57',
#   'bacterium 1XD21-13': '38',
#   'bacterium D16-76': '25',
#   'bacterium 1xD42-87': '24',
#   'bacterium D16-50': '18',
#   'bacterium c-19': '13',
#   'bacterium 1XD8-76': '12',
#   'bacterium D16-63': '5',
#   'bacterium 1xD42-62': '5',
#   'bacterium 1XD42-54': '5',
#   'bacterium 0.1xD8-71': '4',
#   'bacterium LF-3': '3',
#   'bacterium 1XD42-8': '3',
#   'bacterium 0.1xD8-82': '3',
#   'bacterium YEK0313': '2',
#   'bacterium SGD-2': '2',
#   'Candidatus Saccharibacteria': '279',
#   'Candidatus Bipolaricaulota': '1',
#   'Haloplasmataceae': '1',
#   'Fusobacteriales': '483',
#   'Spirochaetales': '83',
#   'Leptospirales': '13',
#   'Brachyspirales': '8',
#   'Synergistales': '99',
#   'Acidobacteriales': '38',
#   'Bryobacterales': '4',
#   'unclassified Acidobacteria (miscellaneous)': '3',
#   'Holophagales': '3',
#   'Thermoanaerobaculales': '1',
#   'Petrotogales': '9',
#   'Kosmotogales': '4',
#   'Thermotogales': '3',
#   'Deferribacterales': '6',
#   'Desulfurobacteriales': '3',
#   'Aquificales': '2',
#   'Elusimicrobiales': '1',
#   'Nitrospirales': '4',
#   'Nitrospinia': '2',
#   'Candidatus Entotheonella': '1',
#   'Coprothermobacterales': '1',
#   'Chrysiogenales': '1',
#   'Thermodesulfobacteriales': '1',
#   'Dictyoglomales': '1',
#   'Methanobacteria': '65578',
#   'Methanococci': '1',
#   'Halobacteria': '42',
#   'Methanomicrobia': '16',
#   'Thermococcales': '9',
#   'Thermoplasmata': '9',
#   'Methanonatronarchaeales': '1',
#   'Candidatus Methanoliparales': '1',
#   'Thermoprotei': '2',
#   'Dikarya': '522',
#   'Fungi incertae sedis': '15'},
#  '4': {'Bacteroidetes': '8841650',
#   'Chlorobi': '50',
#   'Balneolaeota': '10',
#   'Rhodothermaeota': '8',
#   'Ignavibacteriae': '6',
#   'Fibrobacteria': '92',
#   'Gemmatimonadetes': '7',
#   'Candidatus Thermokryptus': '2',
#   'Candidatus Kryptobacter': '2',
#   'Candidatus Chrysopegis': '1',
#   'Candidatus Kryptonium': '1',
#   'Candidatus Marinimicrobia bacterium': '4',
#   'Clostridia': '5675595',
#   'Erysipelotrichia': '352325',
#   'Negativicutes': '95003',
#   'unclassified Firmicutes sensu stricto': '65380',
#   'Bacilli': '42658',
#   'Tissierellia': '1636',
#   'Limnochordia': '4',
#   'Actinobacteria': '842496',
#   'Coriobacteriia': '327116',
#   'Acidimicrobiia': '29',
#   'Thermoleophilia': '15',
#   'Rubrobacteria': '6',
#   'Nitriliruptoria': '4',
#   'unclassified Actinobacteria': '4',
#   'Candidatus Melainabacteria': '1808',
#   'Cyanobacteria': '314',
#   'Candidatus Margulisbacteria': '3',
#   'Mollicutes': '1832',
#   'unclassified Tenericutes': '33',
#   'Candidatus Izimaplasma': '8',
#   'Deinococci': '206',
#   'Anaerolineae': '55',
#   'Dehalococcoidia': '28',
#   'Ktedonobacteria': '14',
#   'Chloroflexia': '13',
#   'Caldilineae': '11',
#   'Ardenticatenia': '6',
#   'Thermomicrobia': '5',
#   'Thermoflexia': '2',
#   'Tepidiformia': '2',
#   'Armatimonadia': '7',
#   'Fimbriimonadia': '1',
#   'Thermobaculum': '1',
#   'Deltaproteobacteria': '133359',
#   'Epsilonproteobacteria': '1279',
#   'Burkholderiales': '46292',
#   'Neisseriales': '130',
#   'Rhodocyclales': '119',
#   'Nitrosomonadales': '64',
#   'unclassified Betaproteobacteria': '19',
#   'Ferrovales': '18',
#   'Pseudomonadales': '5238',
#   'Enterobacterales': '4558',
#   'Pasteurellales': '2248',
#   'Oceanospirillales': '1514',
#   'Xanthomonadales': '338',
#   'Alteromonadales': '309',
#   'Vibrionales': '152',
#   'Aeromonadales': '132',
#   'Chromatiales': '121',
#   'Legionellales': '50',
#   'Cellvibrionales': '49',
#   'Methylococcales': '42',
#   'Thiotrichales': '42',
#   'unclassified Gammaproteobacteria': '26',
#   'Nevskiales': '18',
#   'Cardiobacteriales': '14',
#   'Orbales': '7',
#   'Acidiferrobacterales': '5',
#   'Salinisphaerales': '3',
#   'Rhizobiales': '2779',
#   'Rhodobacterales': '1619',
#   'Rhodospirillales': '929',
#   'Sphingomonadales': '613',
#   'Rickettsiales': '150',
#   'Caulobacterales': '72',
#   'Pelagibacterales': '57',
#   'Kiloniellales': '22',
#   'unclassified Alphaproteobacteria': '19',
#   'Emcibacterales': '14',
#   'Sneathiellales': '12',
#   'Kordiimonadales': '10',
#   'Magnetococcales': '4',
#   'Holosporales': '3',
#   'Micropepsales': '3',
#   'Minwuiales': '2',
#   'Parvularculales': '1',
#   'Bdellovibrionales': '22',
#   'Silvanigrellales': '2',
#   'Bacteriovoracales': '2',
#   'Oligoflexales': '1',
#   'Mariprofundales': '14',
#   'Acidithiobacillales': '7',
#   'Hydrogenophilales': '6',
#   'unclassified Proteobacteria (miscellaneous)': '1',
#   'Verrucomicrobiae': '205571',
#   'Opitutae': '139',
#   'unclassified Verrucomicrobia': '20',
#   'Spartobacteria': '1',
#   'Methylacidiphilae': '1',
#   'Lentisphaeria': '59572',
#   'Planctomycetia': '72',
#   'unclassified Planctomycetes': '41',
#   'Phycisphaerae': '4',
#   'Candidatus Brocadiae': '1',
#   'Chlamydiia': '14',
#   'Kiritimatiellae': '9',
#   'unclassified Kiritimatiellaeota': '3',
#   'bacterium c-19': '357',
#   'bacterium D16-29': '239',
#   'bacterium LF-3': '204',
#   'bacterium 1xD42-67': '181',
#   'bacterium 1XD21-13': '55',
#   'bacterium D16-50': '54',
#   'bacterium 1XD42-54': '34',
#   'bacterium 1xD42-87': '27',
#   'bacterium 1xD42-62': '23',
#   'bacterium 1XD8-92': '18',
#   'bacterium 1XD42-8': '17',
#   'bacterium 1XD8-76': '17',
#   'bacterium 0.1xD8-71': '14',
#   'bacterium D16-63': '13',
#   'bacterium 0.1xD8-82': '12',
#   'bacterium D16-76': '10',
#   'bacterium YEK0313': '2',
#   'bacterium A52C2': '2',
#   'bacterium M00.F.Ca.ET.230.01.1.1': '1',
#   'bacterium JGI 053': '1',
#   'bacterium 1xD42-11': '1',
#   'bacterium 1XD42-1': '1',
#   'Candidatus Saccharibacteria': '115',
#   'Patescibacteria group': '5',
#   'Haloplasmataceae': '38',
#   'Isachenkonia alkalipeptolytica': '4',
#   'Fusobacteriales': '877',
#   'Spirochaetales': '242',
#   'Leptospirales': '56',
#   'Brachyspirales': '46',
#   'Synergistales': '349',
#   'Thermotogales': '113',
#   'Petrotogales': '25',
#   'Kosmotogales': '3',
#   'Mesoaciditogales': '1',
#   'Acidobacteriales': '70',
#   'Bryobacterales': '1',
#   'Holophagales': '11',
#   'Vicinamibacteraceae': '4',
#   'Chloracidobacterium': '1',
#   'Blastocatellales': '1',
#   'Thermoanaerobaculales': '2',
#   'Aquificales': '48',
#   'Desulfurobacteriales': '4',
#   'Deferribacterales': '9',
#   'Nitrospirales': '8',
#   'Thermodesulfobacteriales': '7',
#   'Candidatus Cryosericia': '4',
#   'Dictyoglomales': '4',
#   'Chrysiogenales': '3',
#   'Candidatus Entotheonella': '1',
#   'Coprothermobacterales': '1',
#   'Methanobacteria': '411386',
#   'Methanococci': '14',
#   'Halobacteria': '110',
#   'Methanomicrobia': '22',
#   'Thermoplasmata': '42',
#   'Methanonatronarchaeales': '10',
#   'Thermococcales': '10',
#   'Archaeoglobales': '2',
#   'Methanopyrales': '2',
#   'Thermoprotei': '3',
#   'Nitrosopumilales': '2',
#   'Nitrososphaeria': '1',
#   'Candidatus Methanodesulfokores': '1',
#   'Candidatus Prometheoarchaeum': '1',
#   'Dikarya': '859',
#   'Fungi incertae sedis': '53'},
#  '4_dm': {'Bacteroidetes': 7641675,
#   'Clostridia': 7100403,
#   'Actinobacteria': 586318,
#   'Erysipelotrichia': 367007,
#   'Deltaproteobacteria': 170742,
#   'Coriobacteriia': 202594,
#   'Rhodospirillales': 114327,
#   'Negativicutes': 89525,
#   'Burkholderiales': 49356,
#   'Bacilli': 52997,
#   'Fusobacteriales': 20814,
#   'Verrucomicrobiae': 15595,
#   'Oceanospirillales': 6270,
#   'Enterobacterales': 10255,
#   'Pseudomonadales': 4470,
#   'Tissierellia': 2501,
#   'Synergistales': 1109,
#   'Spirochaetales': 744,
#   'Epsilonproteobacteria': 1120,
#   'Brachyspirales': 594,
#   'Rhizobiales': 347,
#   'Aeromonadales': 488,
#   'Neisseriales': 101},
#  '98': {'Clostridia': '10892262',
#   'unclassified Firmicutes sensu stricto': '519915',
#   'Negativicutes': '126226',
#   'Bacilli': '101486',
#   'Erysipelotrichia': '38917',
#   'Tissierellia': '691',
#   'Limnochordia': '9',
#   'Coriobacteriia': '421559',
#   'Actinobacteria': '227808',
#   'Acidimicrobiia': '9',
#   'Rubrobacteria': '5',
#   'Thermoleophilia': '5',
#   'Nitriliruptoria': '2',
#   'unclassified Actinobacteria': '1',
#   'Candidatus Melainabacteria': '30501',
#   'Cyanobacteria': '381',
#   'Candidatus Margulisbacteria': '2',
#   'Mollicutes': '1154',
#   'Candidatus Izimaplasma': '19',
#   'unclassified Tenericutes': '3',
#   'Dehalococcoidia': '92',
#   'Anaerolineae': '41',
#   'Ktedonobacteria': '11',
#   'Chloroflexia': '6',
#   'Caldilineae': '4',
#   'Thermomicrobia': '2',
#   'Ardenticatenia': '1',
#   'Deinococci': '60',
#   'Chthonomonadetes': '1',
#   'Bacteroidetes': '8069761',
#   'Chlorobi': '12',
#   'Balneolaeota': '8',
#   'Ignavibacteriae': '1',
#   'Fibrobacteria': '65',
#   'Gemmatimonadetes': '2',
#   'Candidatus Cloacimonas': '1',
#   'Candidatus Thermokryptus': '1',
#   'Burkholderiales': '142110',
#   'Rhodocyclales': '2653',
#   'Neisseriales': '35',
#   'Nitrosomonadales': '16',
#   'unclassified Betaproteobacteria': '3',
#   'Ferrovales': '1',
#   'Deltaproteobacteria': '41177',
#   'Epsilonproteobacteria': '299',
#   'Enterobacterales': '10252',
#   'Pseudomonadales': '7202',
#   'Vibrionales': '391',
#   'Alteromonadales': '384',
#   'Oceanospirillales': '359',
#   'Pasteurellales': '336',
#   'Aeromonadales': '138',
#   'Xanthomonadales': '134',
#   'Chromatiales': '50',
#   'Cellvibrionales': '26',
#   'Legionellales': '24',
#   'Thiotrichales': '12',
#   'unclassified Gammaproteobacteria': '12',
#   'Methylococcales': '11',
#   'Orbales': '10',
#   'Nevskiales': '4',
#   'Cardiobacteriales': '2',
#   'Acidiferrobacterales': '2',
#   'Rhizobiales': '939',
#   'Rhodobacterales': '330',
#   'Sphingomonadales': '129',
#   'Rhodospirillales': '99',
#   'Rickettsiales': '50',
#   'Caulobacterales': '44',
#   'Pelagibacterales': '13',
#   'unclassified Alphaproteobacteria': '3',
#   'Emcibacterales': '1',
#   'Sneathiellales': '1',
#   'Kiloniellales': '1',
#   'Holosporales': '1',
#   'Bdellovibrionales': '3',
#   'Silvanigrellales': '1',
#   'Bacteriovoracales': '1',
#   'Acidithiobacillales': '4',
#   'Hydrogenophilales': '3',
#   'Verrucomicrobiae': '122754',
#   'Opitutae': '35',
#   'unclassified Verrucomicrobia': '4',
#   'Methylacidiphilae': '2',
#   'Spartobacteria': '1',
#   'Lentisphaeria': '1980',
#   'Planctomycetia': '38',
#   'unclassified Planctomycetes': '11',
#   'Candidatus Brocadiae': '3',
#   'Phycisphaerae': '1',
#   'Chlamydiia': '3',
#   'Kiritimatiellae': '1',
#   'bacterium D16-76': '188',
#   'bacterium D16-29': '125',
#   'bacterium 0.1xD8-71': '102',
#   'bacterium LF-3': '49',
#   'bacterium 1xD42-62': '48',
#   'bacterium D16-50': '42',
#   'bacterium 1xD42-67': '36',
#   'bacterium 1XD8-76': '32',
#   'bacterium 1XD42-8': '31',
#   'bacterium 1XD42-54': '26',
#   'bacterium 1XD21-13': '23',
#   'bacterium 0.1xD8-82': '11',
#   'bacterium 1xD42-87': '11',
#   'bacterium c-19': '7',
#   'bacterium D16-63': '3',
#   'bacterium 1xD42-11': '2',
#   'Candidatus Saccharibacteria': '128',
#   'Patescibacteria group': '1',
#   'Haloplasmataceae': '2',
#   'unclassified Vampirococcus': '1',
#   'Fusobacteriales': '940',
#   'Acidobacteriales': '28',
#   'Bryobacterales': '4',
#   'Holophagales': '1',
#   'Chloracidobacterium': '1',
#   'Spirochaetales': '148',
#   'Brachyspirales': '23',
#   'Leptospirales': '19',
#   'Synergistales': '163',
#   'Petrotogales': '11',
#   'Thermotogales': '5',
#   'Mesoaciditogales': '1',
#   'Deferribacterales': '9',
#   'Elusimicrobiales': '1',
#   'Nitrospirales': '7',
#   'Aquificales': '4',
#   'Desulfurobacteriales': '1',
#   'Thermodesulfobacteriales': '2',
#   'Dictyoglomales': '2',
#   'Nitrospinia': '1',
#   'Dikarya': '352',
#   'Fungi incertae sedis': '19',
#   'Methanobacteria': '177',
#   'Methanococci': '8',
#   'Halobacteria': '42',
#   'Methanomicrobia': '14',
#   'Candidatus Methanoliparales': '8',
#   'Thermoplasmata': '6',
#   'Thermococcales': '5',
#   'Thermoprotei': '3'},
#  '14': {'Clostridia': '6014197',
#   'Negativicutes': '322151',
#   'Erysipelotrichia': '190301',
#   'unclassified Firmicutes sensu stricto': '97870',
#   'Bacilli': '55543',
#   'Tissierellia': '830',
#   'Limnochordia': '23',
#   'Actinobacteria': '1733460',
#   'Coriobacteriia': '167349',
#   'Thermoleophilia': '10',
#   'Rubrobacteria': '6',
#   'Nitriliruptoria': '6',
#   'unclassified Actinobacteria': '1',
#   'Mollicutes': '1262',
#   'Candidatus Izimaplasma': '114',
#   'unclassified Tenericutes': '4',
#   'Candidatus Melainabacteria': '569',
#   'Cyanobacteria': '393',
#   'Anaerolineae': '129',
#   'Dehalococcoidia': '23',
#   'Caldilineae': '13',
#   'Chloroflexia': '10',
#   'Thermomicrobia': '5',
#   'Ktedonobacteria': '2',
#   'Candidatus Thermofonsia': '1',
#   'Deinococci': '156',
#   'Chthonomonadetes': '3',
#   'Armatimonadia': '1',
#   'unclassified Armatimonadetes': '1',
#   'Thermobaculum': '2',
#   'Bacteroidetes': '7260255',
#   'Chlorobi': '59',
#   'Balneolaeota': '13',
#   'Rhodothermaeota': '8',
#   'Ignavibacteriae': '2',
#   'Fibrobacteria': '439',
#   'Chitinivibrionia': '2',
#   'Candidatus Marinimicrobia bacterium': '2',
#   'Candidatus Chrysopegis': '1',
#   'Burkholderiales': '473175',
#   'Neisseriales': '1415',
#   'Rhodocyclales': '370',
#   'Nitrosomonadales': '41',
#   'unclassified Betaproteobacteria': '16',
#   'Ferrovales': '1',
#   'Deltaproteobacteria': '97893',
#   'Epsilonproteobacteria': '2095',
#   'Enterobacterales': '53507',
#   'Pasteurellales': '17592',
#   'Pseudomonadales': '16520',
#   'Alteromonadales': '396',
#   'Xanthomonadales': '277',
#   'Oceanospirillales': '184',
#   'Chromatiales': '182',
#   'Aeromonadales': '174',
#   'Vibrionales': '125',
#   'Cardiobacteriales': '61',
#   'Legionellales': '60',
#   'Methylococcales': '53',
#   'Cellvibrionales': '43',
#   'Thiotrichales': '42',
#   'unclassified Gammaproteobacteria': '26',
#   'Nevskiales': '20',
#   'Orbales': '6',
#   'Salinisphaerales': '3',
#   'Immundisolibacterales': '2',
#   'Rhizobiales': '4545',
#   'Rhodobacterales': '919',
#   'Rhodospirillales': '430',
#   'Sphingomonadales': '396',
#   'Pelagibacterales': '72',
#   'Caulobacterales': '57',
#   'Rickettsiales': '22',
#   'unclassified Alphaproteobacteria': '5',
#   'Parvularculales': '5',
#   'Kordiimonadales': '2',
#   'Sneathiellales': '2',
#   'Kiloniellales': '1',
#   'Magnetococcales': '1',
#   'Holosporales': '1',
#   'Emcibacterales': '1',
#   'Silvanigrellales': '9',
#   'Bdellovibrionales': '4',
#   'Bacteriovoracales': '4',
#   'Oligoflexales': '2',
# ...
#   'Coriobacteriia': '339457',
#   'Thermoleophilia': '24',
#   'Rubrobacteria': '16',
#   'Acidimicrobiia': '10',
#   'Nitriliruptoria': '6',
#   'unclassified Actinobacteria': '2',
#   'Cyanobacteria': '1107',
#   'Candidatus Melainabacteria': '654',
#   'Candidatus Margulisbacteria': '3',
#   'Mollicutes': '575',
#   'Candidatus Izimaplasma': '12',
#   'unclassified Tenericutes': '4',
#   'Deinococci': '190',
#   'Anaerolineae': '40',
#   'Dehalococcoidia': '35',
#   'Chloroflexia': '25',
#   'Caldilineae': '8',
#   'Ktedonobacteria': '7',
#   'Thermomicrobia': '6',
#   'Candidatus Thermofonsia': '3',
#   'Ardenticatenia': '2',
#   'Thermoflexia': '2',
#   'Tepidiformia': '1',
#   'Armatimonadia': '4',
#   'unclassified Armatimonadetes': '2',
#   'Chthonomonadetes': '2',
#   'Thermobaculum': '4',
#   'Abditibacteria': '1',
#   'Bacteroidetes': '4049173',
#   'Chlorobi': '32',
#   'Balneolaeota': '13',
#   'Rhodothermaeota': '10',
#   'unclassified Bacteroidetes/Chlorobi group': '1',
#   'Ignavibacteriae': '1',
#   'Fibrobacteria': '627',
#   'Chitinivibrionia': '1',
#   'Candidatus Marinimicrobia bacterium': '6',
#   'Gemmatimonadetes': '3',
#   'Candidatus Syntrophosphaera': '1',
#   'Candidatus Thermokryptus': '1',
#   'Candidatus Kryptonium': '1',
#   'Burkholderiales': '30403',
#   'Rhodocyclales': '15771',
#   'Neisseriales': '158',
#   'Nitrosomonadales': '79',
#   'unclassified Betaproteobacteria': '12',
#   'Ferrovales': '2',
#   'Pseudomonadales': '11865',
#   'Enterobacterales': '7540',
#   'Alteromonadales': '663',
#   'Oceanospirillales': '556',
#   'Xanthomonadales': '478',
#   'Pasteurellales': '436',
#   'Aeromonadales': '379',
#   'Vibrionales': '220',
#   'Chromatiales': '135',
#   'Cellvibrionales': '75',
#   'Methylococcales': '41',
#   'Thiotrichales': '39',
#   'unclassified Gammaproteobacteria': '31',
#   'Legionellales': '29',
#   'Nevskiales': '26',
#   'Orbales': '25',
#   'Cardiobacteriales': '14',
#   'Salinisphaerales': '8',
#   'Acidiferrobacterales': '7',
#   'Immundisolibacterales': '1',
#   'Rhizobiales': '2613',
#   'Rhodobacterales': '993',
#   'Sphingomonadales': '626',
#   'Rhodospirillales': '422',
#   'Caulobacterales': '84',
#   'Rickettsiales': '63',
#   'unclassified Alphaproteobacteria': '21',
#   'Pelagibacterales': '17',
#   'Holosporales': '5',
#   'Emcibacterales': '4',
#   'Sneathiellales': '3',
#   'Parvularculales': '2',
#   'Kiloniellales': '2',
#   'Kordiimonadales': '1',
#   'Rhodothalassiales': '1',
#   'Magnetococcales': '1',
#   'Deltaproteobacteria': '7838',
#   'Epsilonproteobacteria': '462',
#   'Bdellovibrionales': '12',
#   'Silvanigrellales': '11',
#   'Oligoflexales': '4',
#   'Bacteriovoracales': '2',
#   'Acidithiobacillales': '6',
#   'Hydrogenophilales': '6',
#   'Mariprofundales': '3',
#   'Lentisphaeria': '1746',
#   'Verrucomicrobiae': '598',
#   'Opitutae': '92',
#   'unclassified Verrucomicrobia': '23',
#   'Spartobacteria': '8',
#   'Methylacidiphilae': '4',
#   'Planctomycetia': '95',
#   'unclassified Planctomycetes': '50',
#   'Phycisphaerae': '7',
#   'Candidatus Brocadiae': '6',
#   'unclassified Kiritimatiellaeota': '9',
#   'Kiritimatiellae': '8',
#   'Chlamydiia': '13',
#   'bacterium 1xD42-67': '158',
#   'bacterium D16-29': '95',
#   'bacterium 1XD42-54': '33',
#   'bacterium D16-50': '31',
#   'bacterium 1XD21-13': '27',
#   'bacterium D16-76': '27',
#   'bacterium 1xD42-87': '26',
#   'bacterium 0.1xD8-82': '18',
#   'bacterium 1XD42-8': '17',
#   'bacterium 1XD8-76': '16',
#   'bacterium 1xD42-62': '16',
#   'bacterium 0.1xD8-71': '14',
#   'bacterium LF-3': '13',
#   'bacterium c-19': '13',
#   'bacterium SGD-2': '6',
#   'bacterium D16-63': '4',
#   'bacterium 1XD8-92': '3',
#   'bacterium YEK0313': '2',
#   'bacterium 1xD42-11': '1',
#   'bacterium J10(2018)': '1',
#   'bacterium JKG1': '1',
#   'bacterium NHP-B': '1',
#   'Candidatus Saccharibacteria': '246',
#   'Patescibacteria group': '2',
#   'candidate division NC10': '1',
#   'Haloplasmataceae': '8',
#   'Isachenkonia alkalipeptolytica': '2',
#   'unclassified Vampirococcus': '1',
#   'Natronospirillum operossus': '1',
#   'Spirochaetales': '273',
#   'Brachyspirales': '62',
#   'Leptospirales': '61',
#   'Brevinematales': '2',
#   'Fusobacteriales': '357',
#   'Synergistales': '273',
#   'Acidobacteriales': '71',
#   'Bryobacterales': '31',
#   'Holophagales': '7',
#   'unclassified Acidobacteria (miscellaneous)': '2',
#   'Blastocatellales': '1',
#   'Thermotogales': '24',
#   'Petrotogales': '21',
#   'Kosmotogales': '9',
#   'Mesoaciditogales': '3',
#   'Aquificales': '18',
#   'Desulfurobacteriales': '6',
#   'Deferribacterales': '20',
#   'Nitrospirales': '16',
#   'Thermodesulfobacteriales': '15',
#   'Endomicrobiales': '2',
#   'Dictyoglomales': '5',
#   'Candidatus Cryosericia': '3',
#   'Nitrospinia': '1',
#   'Candidatus Entotheonella': '1',
#   'Chrysiogenales': '1',
#   'Calditrichales': '1',
#   'Coprothermobacterales': '1',
#   'Methanobacteria': '142024',
#   'Methanococci': '8',
#   'Thermoplasmata': '614',
#   'DHVE2 group': '1',
#   'Halobacteria': '109',
#   'Methanomicrobia': '41',
#   'Thermococcales': '7',
#   'Archaeoglobales': '3',
#   'Methanopyrales': '1',
#   'Candidatus Methanoliparales': '1',
#   'Nitrosopumilales': '4',
#   'Nitrososphaeria': '4',
#   'unclassified Thaumarchaeota': '1',
#   'Thermoprotei': '7',
#   'Candidatus Prometheoarchaeum': '1',
#   'Dikarya': '1469',
#   'Fungi incertae sedis': '79'},
#  '100_dm': {'Bacteroidetes': 7551747,
#   'Clostridia': 5980450,
#   'Erysipelotrichia': 629213,
#   'Actinobacteria': 394483,
#   'Negativicutes': 477239,
#   'Coriobacteriia': 225181,
#   'Deltaproteobacteria': 85570,
#   'Burkholderiales': 43009,
#   'Bacilli': 54177,
#   'Fusobacteriales': 9600,
#   'Oceanospirillales': 5243,
#   'Pseudomonadales': 3385,
#   'Enterobacterales': 6966,
#   'Rhodospirillales': 1011,
#   'Tissierellia': 1555,
#   'Epsilonproteobacteria': 1196,
#   'Verrucomicrobiae': 611,
#   'Spirochaetales': 608,
#   'Synergistales': 469,
#   'Brachyspirales': 427,
#   'Aeromonadales': 616,
#   'Rhizobiales': 172,
#   'Neisseriales': 68},
#  '2': {'Clostridia': '10456257',
#   'Negativicutes': '201130',
#   'unclassified Firmicutes sensu stricto': '111690',
#   'Bacilli': '73546',
#   'Erysipelotrichia': '38188',
#   'Tissierellia': '1116',
#   'Limnochordia': '12',
#   'Actinobacteria': '1287961',
#   'Coriobacteriia': '237087',
#   'Thermoleophilia': '19',
#   'Rubrobacteria': '12',
#   'Nitriliruptoria': '8',
#   'Acidimicrobiia': '5',
#   'Candidatus Melainabacteria': '185776',
#   'Cyanobacteria': '343',
#   'Candidatus Margulisbacteria': '2',
#   'Mollicutes': '1396',
#   'Candidatus Izimaplasma': '106',
#   'unclassified Tenericutes': '4',
#   'Deinococci': '260',
#   'Anaerolineae': '69',
#   'Chloroflexia': '27',
#   'Ktedonobacteria': '17',
#   'Dehalococcoidia': '10',
#   'Thermomicrobia': '7',
#   'Caldilineae': '7',
#   'Ardenticatenia': '6',
#   'Thermoflexia': '5',
#   'Candidatus Thermofonsia': '1',
#   'Armatimonadia': '3',
#   'Chthonomonadetes': '1',
#   'Fimbriimonadia': '1',
#   'Abditibacteria': '4',
#   'Bacteroidetes': '5715868',
#   'Chlorobi': '29',
#   'Balneolaeota': '15',
#   'Rhodothermaeota': '14',
#   'unclassified Bacteroidetes/Chlorobi group': '3',
#   'Ignavibacteriae': '2',
#   'Fibrobacteria': '254',
#   'Chitinivibrionia': '1',
#   'Gemmatimonadetes': '6',
#   'Candidatus Marinimicrobia bacterium': '4',
#   'Candidatus Thermokryptus': '4',
#   'Candidatus Cloacimonas': '1',
#   'Candidatus Syntrophosphaera': '1',
#   'candidate division Zixibacteria bacterium': '1',
#   'Burkholderiales': '99285',
#   'Neisseriales': '315',
#   'Rhodocyclales': '162',
#   'Nitrosomonadales': '145',
#   'unclassified Betaproteobacteria': '12',
#   'Ferrovales': '1',
#   'Deltaproteobacteria': '64919',
#   'Epsilonproteobacteria': '828',
#   'Rhizobiales': '4609',
#   'Rhodobacterales': '2433',
#   'Rhodospirillales': '1575',
#   'Sphingomonadales': '1071',
#   'Caulobacterales': '152',
#   'Rickettsiales': '98',
#   'unclassified Alphaproteobacteria': '49',
#   'Pelagibacterales': '31',
#   'Holosporales': '12',
#   'Emcibacterales': '11',
#   'Kiloniellales': '10',
#   'Sneathiellales': '5',
#   'Parvularculales': '4',
#   'Minwuiales': '2',
#   'Rhodothalassiales': '2',
#   'Magnetococcales': '2',
#   'Kordiimonadales': '2',
#   'Enterobacterales': '9420',
#   'Pseudomonadales': '3813',
#   'Pasteurellales': '837',
#   'Alteromonadales': '703',
#   'Xanthomonadales': '460',
#   'Oceanospirillales': '319',
#   'Vibrionales': '249',
#   'Chromatiales': '127',
#   'Methylococcales': '118',
#   'Aeromonadales': '114',
#   'Cellvibrionales': '77',
#   'Thiotrichales': '63',
#   'unclassified Gammaproteobacteria': '45',
#   'Nevskiales': '35',
#   'Legionellales': '24',
#   'Cardiobacteriales': '11',
#   'Orbales': '9',
#   'Acidiferrobacterales': '9',
#   'Salinisphaerales': '8',
#   'Immundisolibacterales': '2',
#   'Arenicellales': '1',
#   'Oligoflexales': '12',
#   'Bdellovibrionales': '10',
#   'Silvanigrellales': '5',
#   'Bacteriovoracales': '2',
#   'Hydrogenophilales': '13',
#   'Acidithiobacillales': '7',
#   'Mariprofundales': '2',
#   'Verrucomicrobiae': '95986',
#   'Opitutae': '484',
#   'Spartobacteria': '97',
#   'unclassified Verrucomicrobia': '33',
#   'Lentisphaeria': '18234',
#   'Planctomycetia': '91',
#   'unclassified Planctomycetes': '58',
#   'Candidatus Brocadiae': '11',
#   'Phycisphaerae': '5',
#   'Kiritimatiellae': '8',
#   'unclassified Kiritimatiellaeota': '7',
#   'Chlamydiia': '16',
#   'bacterium LF-3': '4144',
#   'bacterium D16-29': '400',
#   'bacterium 1xD42-67': '194',
#   'bacterium D16-76': '156',
#   'bacterium 1XD21-13': '152',
#   'bacterium 0.1xD8-71': '97',
#   'bacterium D16-50': '80',
#   'bacterium 1XD8-76': '51',
#   'bacterium 1xD42-87': '51',
#   'bacterium 1XD42-54': '51',
#   'bacterium 1xD42-62': '39',
#   'bacterium 0.1xD8-82': '34',
#   'bacterium JKG1': '21',
#   'bacterium 1XD42-8': '11',
#   'bacterium D16-63': '7',
#   'bacterium c-19': '7',
#   'bacterium 1xD42-11': '5',
#   'bacterium 1XD8-92': '3',
#   'bacterium 1XD42-1': '1',
#   'bacterium A52C2': '1',
#   'bacterium endosymbiont of Pedicinus badii': '1',
#   'bacterium YEK0313': '1',
#   'Candidatus Saccharibacteria': '91',
#   'Patescibacteria group': '6',
#   'candidate division NC10': '4',
#   'Candidatus Dependentiae': '2',
#   'Haloplasmataceae': '5',
#   'unclassified Vampirococcus': '1',
#   'Natronospirillum operossus': '1',
#   'Isachenkonia alkalipeptolytica': '1',
#   'Fusobacteriales': '843',
#   'Spirochaetales': '425',
#   'Leptospirales': '72',
#   'Brachyspirales': '57',
#   'Brevinematales': '1',
#   'Synergistales': '317',
#   'Acidobacteriales': '88',
#   'Bryobacterales': '12',
#   'unclassified Acidobacteriia': '1',
#   'Holophagales': '5',
#   'unclassified Acidobacteria (miscellaneous)': '2',
#   'Thermotogales': '27',
#   'Petrotogales': '13',
#   'Kosmotogales': '10',
#   'Desulfurobacteriales': '16',
#   'Aquificales': '12',
#   'Nitrospirales': '24',
#   'Nitrospirae bacterium HCH-1': '1',
#   'Deferribacterales': '22',
#   'Elusimicrobiales': '4',
#   'Thermodesulfobacteriales': '16',
#   'Dictyoglomales': '2',
#   'Coprothermobacterales': '1',
#   'Chrysiogenales': '1',
#   'Methanobacteria': '89552',
#   'Methanococci': '4',
#   'Halobacteria': '174',
#   'Methanomicrobia': '34',
#   'Thermoplasmata': '19',
#   'Thermococcales': '11',
#   'Archaeoglobales': '1',
#   'Methanopyrales': '1',
#   'Thermoprotei': '7',
#   'Nitrosopumilales': '5',
#   'unclassified Thaumarchaeota': '2',
#   'Dikarya': '1194',
#   'Fungi incertae sedis': '43'},
#  '99': {'Clostridia': '11073469',
#   'Erysipelotrichia': '552142',
#   'Negativicutes': '333752',
#   'Bacilli': '136320',
#   'unclassified Firmicutes sensu stricto': '79677',
#   'Tissierellia': '1738',
#   'Limnochordia': '11',
#   'Coriobacteriia': '491745',
#   'Actinobacteria': '160817',
#   'Thermoleophilia': '15',
#   'Rubrobacteria': '9',
#   'Nitriliruptoria': '6',
#   'unclassified Actinobacteria': '1',
#   'Candidatus Melainabacteria': '307567',
#   'Cyanobacteria': '213',
#   'Candidatus Margulisbacteria': '5',
#   'Mollicutes': '366',
#   'Candidatus Izimaplasma': '23',
#   'unclassified Tenericutes': '7',
#   'Deinococci': '156',
#   'Anaerolineae': '57',
#   'Chloroflexia': '20',
#   'Ktedonobacteria': '18',
#   'Dehalococcoidia': '17',
#   'Caldilineae': '15',
#   'Ardenticatenia': '9',
#   'Thermomicrobia': '2',
#   'Thermoflexia': '2',
#   'Candidatus Thermofonsia': '1',
#   'Tepidiformia': '1',
#   'Chthonomonadetes': '2',
#   'Armatimonadia': '1',
#   'unclassified Armatimonadetes': '1',
#   'Fimbriimonadia': '1',
#   'Bacteroidetes': '4266855',
#   'Chlorobi': '43',
#   'Balneolaeota': '10',
#   'Rhodothermaeota': '7',
#   'unclassified Bacteroidetes/Chlorobi group': '1',
#   'Fibrobacteria': '243',
#   'Gemmatimonadetes': '7',
#   'Candidatus Marinimicrobia bacterium': '2',
#   'Candidatus Thermokryptus': '1',
#   'Verrucomicrobiae': '430135',
#   'Opitutae': '153',
#   'Spartobacteria': '15',
#   'unclassified Verrucomicrobia': '9',
#   'Lentisphaeria': '9857',
#   'Planctomycetia': '72',
#   'unclassified Planctomycetes': '56',
#   'Phycisphaerae': '4',
#   'Candidatus Brocadiae': '1',
#   'Chlamydiia': '23',
#   'Kiritimatiellae': '12',
#   'unclassified Kiritimatiellaeota': '7',
#   'Burkholderiales': '236431',
#   'Rhodocyclales': '462',
#   'Neisseriales': '200',
#   'Nitrosomonadales': '60',
#   'unclassified Betaproteobacteria': '16',
#   'Ferrovales': '2',
#   'Epsilonproteobacteria': '28963',
#   'Deltaproteobacteria': '19810',
#   'Enterobacterales': '27680',
#   'Pseudomonadales': '5394',
#   'Alteromonadales': '1337',
#   'Pasteurellales': '1208',
#   'Xanthomonadales': '366',
#   'Oceanospirillales': '189',
#   'Aeromonadales': '129',
#   'Vibrionales': '118',
#   'Chromatiales': '99',
#   'Cellvibrionales': '65',
#   'Thiotrichales': '33',
#   'Cardiobacteriales': '31',
#   'unclassified Gammaproteobacteria': '29',
#   'Methylococcales': '27',
#   'Legionellales': '25',
#   'Nevskiales': '18',
#   'Salinisphaerales': '4',
#   'Orbales': '3',
#   'Immundisolibacterales': '1',
#   'Rhizobiales': '2348',
#   'Rhodobacterales': '881',
#   'Sphingomonadales': '441',
#   'Rhodospirillales': '296',
#   'Caulobacterales': '59',
#   'Rickettsiales': '33',
#   'Pelagibacterales': '25',
#   'unclassified Alphaproteobacteria': '14',
#   'Holosporales': '2',
#   'Minwuiales': '1',
#   'Magnetococcales': '1',
#   'Sneathiellales': '1',
#   'Kordiimonadales': '1',
#   'Parvularculales': '1',
#   'Silvanigrellales': '9',
#   'Bdellovibrionales': '3',
#   'Oligoflexales': '2',
#   'Bacteriovoracales': '1',
#   'Hydrogenophilales': '8',
#   'Mariprofundales': '4',
#   'Acidithiobacillales': '2',
#   'bacterium LF-3': '440',
#   'bacterium 1xD42-67': '258',
#   'bacterium D16-29': '178',
#   'bacterium c-19': '151',
#   'bacterium D16-50': '84',
#   'bacterium D16-76': '66',
#   'bacterium 1XD21-13': '51',
#   'bacterium 1XD8-76': '40',
#   'bacterium 1xD42-87': '31',
#   'bacterium 1XD42-8': '29',
#   'bacterium 1XD42-54': '27',
#   'bacterium 0.1xD8-82': '18',
#   'bacterium 1xD42-62': '16',
#   'bacterium 0.1xD8-71': '16',
#   'bacterium D16-63': '7',
#   'bacterium 1XD8-92': '4',
#   'bacterium A37T11': '2',
#   'bacterium JKG1': '2',
#   'bacterium YEK0313': '2',
#   'bacterium 1XD42-1': '1',
#   'bacterium 2013Arg42i': '1',
#   'bacterium BCRC 81129': '1',
#   'Candidatus Saccharibacteria': '182',
#   'Patescibacteria group': '2',
#   'Candidatus Bipolaricaulota': '1',
#   'Candidatus Atribacteria': '1',
#   'Isachenkonia alkalipeptolytica': '8',
#   'Haloplasmataceae': '3',
#   'Natronospirillum operossus': '1',
#   'Fusobacteriales': '1156',
#   'Spirochaetales': '245',
#   'Brachyspirales': '82',
#   'Leptospirales': '47',
#   'Synergistales': '275',
#   'Acidobacteriales': '42',
#   'Bryobacterales': '21',
#   'Holophagales': '21',
#   'Blastocatellales': '2',
#   'Thermoanaerobaculales': '2',
#   'Vicinamibacteraceae': '2',
#   'Petrotogales': '20',
#   'Thermotogales': '14',
#   'Kosmotogales': '8',
#   'Mesoaciditogales': '1',
#   'Nitrospirales': '16',
#   'Nitrospirae bacterium HCH-1': '1',
#   'Aquificales': '8',
#   'Desulfurobacteriales': '3',
#   'Elusimicrobiales': '2',
#   'Deferribacterales': '7',
#   'Thermodesulfobacteriales': '4',
#   'Candidatus Cryosericia': '3',
#   'Chrysiogenales': '3',
#   'Calditrichales': '2',
#   'Dictyoglomales': '1',
#   'Nitrospinia': '1',
#   'Coprothermobacterales': '1',
#   'Methanobacteria': '34705',
#   'Methanococci': '4',
#   'Halobacteria': '92',
#   'Methanomicrobia': '36',
#   'Thermococcales': '57',
#   'Thermoplasmata': '9',
#   'Archaeoglobales': '1',
#   'Methanopyrales': '1',
#   'Thermoprotei': '3',
#   'unclassified Thaumarchaeota': '1',
#   'Nitrososphaeria': '1',
#   'unclassified Candidatus Bathyarchaeota': '1',
#   'Dikarya': '1389',
#   'Fungi incertae sedis': '33'}}

# %%
# data as stacked bar charts
data = {
    "Organism": [],
    "Read Count": [],
    "Sample": []
}
samples = []
min_reads = 0
total_others = []

with open('kraken2.csv', 'r') as f:
    raw_data = f.read().split("\n")
    
    samples = ["Sample "+x for x in raw_data[0].split(",") if x != ""]
    for s in samples:
        total_others.append(0)
    
    for r in raw_data[1:]:
        do_add = False
        tmp_new = [0 for s in samples]
        
        tmp_r = r.split(",")
        if len(tmp_r) > 1: # dealing with the last row
            org = "|".join([x for x in tmp_r[:-len(samples)] if x != "-"])

            for i in range(0, len(samples)):
                tmp_new[i] = tmp_r[-len(samples)+i]
                
                if tmp_new[i] != "NaN" and int(tmp_new[i]) >= min_reads:
                    do_add = True
                
            if do_add:
                for i in range(0, len(samples)):
                    data["Organism"].append(org)
                    data["Read Count"].append(tmp_new[i])
                    data["Sample"].append(samples[i])
            else:
                for i in range(0, len(samples)):
                    if tmp_new[i] != "NaN":
                        total_others[i] += int(tmp_new[i])
    
for i in range(0, len(samples)):
    data["Organism"].append("other")
    data["Read Count"].append(total_others[i])
    data["Sample"].append(samples[i])
    
df = pd.DataFrame.from_dict(data)
df["Read Count"] = df["Read Count"].astype(float)

# %%
fig = px.bar(df, x="Sample", y="Read Count", color='Organism')
fig.update_layout(showlegend=False)
fig.write_html("kraken2.html")
fig.show()
# Out:
# <div>
#
#
#             <div id="9c61fd74-df21-4958-8146-25523edb1e5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c61fd74-df21-4958-8146-25523edb1e5b")) {
#                     Plotly.newPlot(
#                         '9c61fd74-df21-4958-8146-25523edb1e5b',
#                         [{"alignmentgroup": "True", "hovertemplate": "Organism=Phycisphaerae<br>Sample=%{x}<br>Read Count=%{y}<extra></extra>", "legendgroup": "Phycisphaerae", "marker": {"color": "#636efa"}, "name": "Phycisphaerae", "offsetgroup": "Phycisphaerae", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sample 104", "Sample 104_dm", "Sample 1", "Sample 1_dm", "Sample 16", "Sample 97", "Sample 97_dm", "Sample 13", "Sample 15", "Sample 101", "Sample 3", "Sample 4", "Sample 4_dm", "Sample 98", "Sample 14", "Sample 14_dm", "Sample 103", "Sample 100", "Sample 100_dm", "Sample 2", "Sample 99"], "xaxis": "x", "y": [null, null, null, null, 3.0, 3.0, null, 12.0, 5.0, 1.0, 5.0, 4.0, null, 1.0, 8.0, null, null, 7.0, null, 5.0, 4.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Organism=Methanopyrales<br>Sample=%{x}<br>Read Count=%{y}<extra></extra>", "legendgroup": "Methanopyrales", "marker": {"color": "#EF553B"}, "name": "Methanopyrales", "offsetgroup": "Methanopyrales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sample 104", "Sample 104_dm", "Sample 1", "Sample 1_dm", "Sample 16", "Sample 97", "Sample 97_dm", "Sample 13", "Sample 15", "Sample 101", "Sample 3", "Sample 4", "Sample 4_dm", "Sample 98", "Sample 14", "Sample 14_dm", "Sample 103", "Sample 100", "Sample 100_dm", "Sample 2", "Sample 99"], "xaxis": "x", "y": [null, null, 1.0, null, 2.0, 4.0, null, null, 1.0, null, null, 2.0, null, null, 3.0, null, null, 1.0, null, 1.0, 1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Organism=unclassified Acidobacteria (miscellaneous)<br>Sample=%{x}<br>Read Count=%{y}<extra></extra>", "legendgroup": "unclassified Acidobacteria (miscellaneous)", "marker": {"color": "#00cc96"}, "name": "unclassified Acidobacteria (miscellaneous)", "offsetgroup": "unclassified Acidobacteria (miscellaneous)", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sample 104", "Sample 104_dm", "Sample 1", "Sample 1_dm", "Sample 16", "Sample 97", "Sample 97_dm", "Sample 13", "Sample 15", "Sample 101", "Sample 3", "Sample 4", "Sample 4_dm", "Sample 98", "Sample 14", "Sample 14_dm", "Sample 103", "Sample 100", "Sample 100_dm", "Sample 2", "Sample 99"], "xaxis": "x", "y": [1.0, null, null, null, null, 1.0, null, 2.0, null, null, 3.0, null, null, null, null, null, null, 2.0, null, 2.0, null], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Organism=bacterium D16-29<br>Sample=%{x}<br>Read Count=%{y}<extra></extra>", "legendgroup": "bacterium D16-29", "marker": {"color": "#ab63fa"}, "name": "bacterium D16-29", "offsetgroup": "bacterium D16-29", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sample 104", "Sample 104_dm", "Sample 1", "Sample 1_dm", "Sample 16", "Sample 97", "Sample 97_dm", "Sample 13", "Sample 15", "Sample 101", "Sample 3", "Sample 4", "Sample 4_dm", "Sample 98", "Sample 14", "Sample 14_dm", "Sample 103", "Sample 100", "Sample 100_dm", "Sample 2", "Sample 99"], "xaxis": "x", "y": [24.0, null, 189.0, null, 122.0, 133.0, null, 198.0, 158.0, 17.0, 68.0, 239.0, null, 125.0, 164.0, null, 13.0, 95.0, null, 400.0, 178.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Organism=Candidatus Methanoliparales<br>Sample=%{x}<br>Read Count=%{y}<extra></extra>", "legendgroup": "Candidatus Methanoliparales", "marker": {"color": "#FFA15A"}, "name": "Candidatus Methanoliparales", "offsetgroup": "Candidatus Methanoliparales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sample 104", "Sample 104_dm", "Sample 1", "Sample 1_dm", "Sample 16", "Sample 97", "Sample 97_dm", "Sample 13", "Sample 15", "Sample 101", "Sample 3", "Sample 4", "Sample 4_dm", "Sample 98", "Sample 14", "Sample 14_dm", "Sample 103", "Sample 100", "Sample 100_dm", "Sample 2", "Sample 99"], "xaxis": "x", "y": [null, null, null, null, null, null, null, null, nu ...
