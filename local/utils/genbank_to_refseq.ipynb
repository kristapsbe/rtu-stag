# %%
import os
import wget
import ftplib
import pathlib

# %%
ncbi = "ftp.ncbi.nlm.nih.gov"
src = "/refseq/release/bacteria/"

# use the ftp lib to pull the file list
ftp = ftplib.FTP()
ftp.connect(ncbi)
ftp.login()

# need to make sure that the dirs that we're downloading stuff to exist
pathlib.Path(os.getcwd()+src).mkdir(parents=True, exist_ok=True) 

# work through all of the bacteria genome files
for f in ftp.nlst(src):
    if ".genomic.fna.gz" in f:
        path = os.getcwd()+f # making an absolute path
        
        if os.path.isfile(path):
            print(f+" already present")
        else:
            print("Fetching "+f)
            # couldn't figure out how to pull files via the ftp library - using wget for this
            wget.download("ftp://"+ncbi+f, out=path)
# Out:
# /refseq/release/bacteria/bacteria.1821.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1827.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.220.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.215.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.945.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.6.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.603.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.607.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.608.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.606.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.370.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.371.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.630.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.962.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.236.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.234.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.237.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.703.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1389.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1489.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1486.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.880.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.990.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.992.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.658.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.659.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1037.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1038.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2016.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2015.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.240.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1657.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.129.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1290.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.201.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.362.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.104.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.327.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.466.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.47.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.470.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.471.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1824.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1402.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1404.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1321.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.598.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.588.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.579.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.581.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.343.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.342.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.332.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.936.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.933.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.935.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1602.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.152.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.960.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1414.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2048.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.610.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.612.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.361.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.860.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1836.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.427.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.425.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.429.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1842.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1841.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1585.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1849.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1850.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.185.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1851.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.994.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.273.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.269.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.26.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.306.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1552.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1551.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.592.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.590.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.593.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1450.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.689.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1615.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1620.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1621.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1039.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.620.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1121.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1130.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1131.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1022.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2044.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2047.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.582.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1202.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.827.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.528.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.698.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.70.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.7.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1613.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1186.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1195.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1190.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1183.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1181.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.367.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.368.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.861.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.867.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.575.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.97.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.971.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.974.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2046.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1040.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1041.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.769.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.765.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.766.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1194.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.982.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1786.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.259.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.254.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.258.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.253.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.261.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.260.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.312.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.313.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.31.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.73.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.322.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.321.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.323.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1488.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1479.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.252.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.488.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1008.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1011.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1206.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1328.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2020.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.202.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.552.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.561.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.609.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.767.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.172.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1720.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1839.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2026.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1895.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1897.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1357.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.805.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1761.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1763.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.512.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.415.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.422.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.626.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.628.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1184.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.379.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.830.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.749.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1160.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1161.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.116.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1666.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1670.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.167.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1269.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2018.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2019.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1975.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1977.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.373.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.375.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.374.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.376.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.898.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1103.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1830.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.474.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1207.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1091.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.109.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1090.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1092.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1886.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.713.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1240.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1241.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1238.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1432.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1711.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1713.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1911.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2039.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.810.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1748.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1015.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.289.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.291.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1358.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.902.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.897.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1107.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.625.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.50.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.346.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.345.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.210.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.211.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1521.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1522.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1243.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.33.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1173.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1174.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1175.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1176.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.678.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.336.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.864.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.639.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1396.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1399.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.932.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.651.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.66.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1550.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1876.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.952.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.955.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1671.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.682.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.692.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.694.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1279.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1634.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1636.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1273.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1077.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1072.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1074.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1078.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.734.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1731.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.48.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1109.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.2014.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1546.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria.1545.1.genomic.fna.gz already present
# /refseq/release/bacteria/bacteria
1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.433.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.437.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.436.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.772.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.771.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1177.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.118.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1805.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1804.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1806.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1341.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.394.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.997.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.991.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.711.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1973.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1084.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1082.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.53.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1401.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1796.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1262.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1236.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1158.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1159.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1050.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1044.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.464.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1214.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1865.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1867.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1482.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1478.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1743.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1742.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1747.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1746.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.473.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.2041.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1304.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.405.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.71.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.704.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.710.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.356.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1505.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1503.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1956.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1558.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1547.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1751.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.38.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.380.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.381.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1631.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.107.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.987.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.999.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.162.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1622.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1624.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1364.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.951.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1759.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.19.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.837.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1680.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1679.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1677.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.576.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.68.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1775.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.2002.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1954.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1778.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1717.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1797.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1919.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1920.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1473.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.947.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.2040.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.41.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.137.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1376.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1060.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.895.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.893.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.891.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.894.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1835.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1838.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.665.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.732.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.733.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.731.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.786.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1757.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.334.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.335.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.463.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.469.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1459.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.1463.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.205.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.2043.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.2057.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.21.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.216.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.214.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.690.1.genomic.fna.gz
# Fetching /refseq/release/bacteria/bacteria.69.1.genomic.fna.gz

# %%
ncbi = "ftp.ncbi.nlm.nih.gov"
src = "/refseq/release/archaea/"

# use the ftp lib to pull the file list
ftp = ftplib.FTP()
ftp.connect(ncbi)
ftp.login()

# need to make sure that the dirs that we're downloading stuff to exist
pathlib.Path(os.getcwd()+src).mkdir(parents=True, exist_ok=True) 

# work through all of the bacteria genome files
for f in ftp.nlst(src):
    if ".genomic.fna.gz" in f:
        path = os.getcwd()+f # making an absolute path
        
        if os.path.isfile(path):
            print(f+" already present")
        else:
            print("Fetching "+f)
            # couldn't figure out how to pull files via the ftp library - using wget for this
            wget.download("ftp://"+ncbi+f, out=path)

# %%
ncbi = "ftp.ncbi.nlm.nih.gov"
src = "/refseq/release/fungi/"

# use the ftp lib to pull the file list
ftp = ftplib.FTP()
ftp.connect(ncbi)
ftp.login()

# need to make sure that the dirs that we're downloading stuff to exist
pathlib.Path(os.getcwd()+src).mkdir(parents=True, exist_ok=True) 

# work through all of the bacteria genome files
for f in ftp.nlst(src):
    if ".genomic.fna.gz" in f:
        path = os.getcwd()+f # making an absolute path
        
        if os.path.isfile(path):
            print(f+" already present")
        else:
            print("Fetching "+f)
            # couldn't figure out how to pull files via the ftp library - using wget for this
            wget.download("ftp://"+ncbi+f, out=path)

# %%
ncbi = "ftp.ncbi.nlm.nih.gov"
src = "/genbank/"

# use the ftp lib to pull the file list
ftp = ftplib.FTP()
ftp.connect(ncbi)
ftp.login()

# need to make sure that the dirs that we're downloading stuff to exist
pathlib.Path(os.getcwd()+src).mkdir(parents=True, exist_ok=True) 

# work through all of the bacteria genome files
for f in ftp.nlst(src):
    if ".seq.gz" in f:
        path = os.getcwd()+f # making an absolute path
        
        if os.path.isfile(path):
            print(f+" already present")
        else:
            print("Fetching "+f)
            # couldn't figure out how to pull files via the ftp library - using wget for this
            wget.download("ftp://"+ncbi+f, out=path)
